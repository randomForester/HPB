# %%
import pandas as pd
import matplotlib.pyplot as plt
#%config InlineBackend.figure_format ='svg'

df = pd.read_csv('UN_CO2_emmisions_data_kilotonne.csv',index_col='Year', parse_dates=['Year'])

df.Monaco = pd.to_numeric(df.Monaco, errors='coerce')

# %%
df.head()
# Out:
#                 Australia       Austria        Belarus        Belgium  \
# Year
# 1990-01-01  278265.898941  62297.165568  100438.095064  119982.503419
# 1991-01-01  279741.639012  65903.513308   93649.166141  123130.652897
# 1992-01-01  284766.092718  60432.249341   87060.810290  122217.919518
# 1993-01-01  289142.267681  60790.757721   75551.755292  121156.964955
# 1994-01-01  293830.709141  61189.102505   62402.279083  124426.885710
#
#                 Bulgaria         Canada       Croatia       Cyprus  \
# Year
# 1990-01-01  78197.881257  463493.332388  23390.075209  4621.007177
# 1991-01-01  59769.341503  454246.137946  17268.910346  5107.082887
# 1992-01-01  56551.593572  468546.458912  16607.134479  5482.974870
# 1993-01-01  57203.935518  467607.237235  17081.228023  5733.674102
# 1994-01-01  55649.081315  482691.671272  16342.181876  5977.257105
#
#             Czech Republic       Denmark            ...             \
# Year                                                ...
# ...

# %%
df_totals = df.sum(axis=0).sort_values()
df_totals = df.sum(axis=0).sort_values()[:5]
df_totals = df.sum(axis=0).sort_values()[-9:]

ax = df_totals.plot(kind='bar', figsize=(13,7) ,title='CO$_2$ Emission $_{(1990-2014)}$')
ax.set_ylabel('CO$_2$ (ktonnes)')
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()

# %%
df['Australia'].plot()
plt.show()
