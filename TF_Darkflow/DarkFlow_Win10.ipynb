# %%
# !dir
# Out:
#  磁碟區 E 中的磁碟是 新增磁碟區
#  磁碟區序號:  EA0D-3591
#
#  E:\Test\darkflow-master 的目錄
#
# 2018/03/09  下午 06:13    <DIR>          .
# 2018/03/09  下午 06:13    <DIR>          ..
# 2018/02/26  上午 07:07                19 .coveragerc
# 2018/02/26  上午 07:07               538 .gitignore
# 2018/03/08  下午 05:23    <DIR>          .ipynb_checkpoints
# 2018/02/26  上午 07:07               355 .travis.yml
# 2018/03/08  下午 03:03    <DIR>          bin
# 2018/03/08  下午 02:58    <DIR>          build
# 2018/03/08  下午 05:22    <DIR>          cfg
# 2018/03/09  下午 05:58    <DIR>          ckpt
# 2018/03/08  下午 02:58    <DIR>          darkflow
# 2018/03/08  下午 05:33            20,644 DarkFlow_Win.ipynb
# 2018/03/09  下午 06:13            18,786 DarkFlow_Win10.ipynb
# 2018/02/26  上午 07:07        14,900,940 demo.gif
# 2018/02/26  上午 07:07                94 flow
# 2018/03/07  下午 06:08               216 flow2.py
# 2018/03/08  下午 02:28               105 flow3.py
# 2018/03/08  下午 05:22                21 labels.txt
# ...

# %%
# !python flow2.py --h
# Out:
# Example usage: flow --imgdir sample_img/ --model cfg/yolo.cfg --load bin/yolo.weights
#
# Arguments:
#   --help, --h, -h  show this super helpful message and exit
#   --imgdir         path to testing directory with images
#   --binary         path to .weights directory
#   --config         path to .cfg directory
#   --dataset        path to dataset directory
#   --labels         path to labels file
#   --backup         path to backup folder
#   --summary        path to TensorBoard summaries directory
#   --annotation     path to annotation directory
#   --threshold      detection threshold
#   --model          configuration of choice
#   --trainer        training algorithm
#   --momentum       applicable for rmsprop and momentum optimizers
#   --verbalise      say out loud while building graph
#   --train          train the whole net
#   --load           how to initialize the net? Either from .weights or a checkpoint, or even from scratch
# ...

# %%
# !python flow2.py --model cfg/tiny-yolo.cfg --load bin/tiny-yolo-voc.weights
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.0s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
# ...

# %%
# !python flow2.py --imgdir sample_img/ --model cfg/tiny-yolo.cfg --load bin/tiny-yolo-voc.weights
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.01562643051147461s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
# ...

# %%
# !python flow2.py --imgdir sample_img/ --model cfg/tiny-yolo.cfg --load bin/tiny-yolo-voc.weights --json
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.0s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
# ...

# %% [markdown]
# # Training and Testing

# %% [markdown]
# Script for 3 classes
# ==
#
# Train: (3C)
# ==
# ./flow --model cfg/tiny-yolo-voc-3c.cfg --train --dataset "../MY20173c/JPEGImages" --annotation "../MY20173c/Annotations" --epoch 1000 --trainer adam --load bin/tiny-yolo-voc.weights
#
# Test: (3C)
# ==
# ./flow --imgdir "../MY20173c_test/" --model cfg/tiny-yolo-voc-3c.cfg --load -1 --lr 0.0001 --batch 32
#
# Script for 1 class
# ==
#
# Train: (1C)
# ==
# ./flow --model cfg/tiny-yolo-voc-1c.cfg --train --dataset "../MY2017/JPEGImages" --annotation "../MY2017/Annotations" --epoch 5 --trainer adam --load bin/tiny-yolo-voc.weights
#
# Test: (1C)
# ==
# ./flow --imgdir "../MY2017_test/" --model cfg/tiny-yolo-voc-1c.cfg --load bin/tiny-yolo-voc.weights --lr 0.0001 --batch 32

# %%
# !python flow2.py --model cfg/tiny-yolo-voc-3c.cfg --train --dataset "../darkflow_data/MY20173c/JPEGImages" --annotation "../darkflow_data/MY20173c/Annotations" --epoch 35 --trainer adam --load bin/tiny-yolo-voc.weights
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo-voc-3c.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.0s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
# ...

# %%
# !python flow2.py --imgdir "../darkflow_data/MY20173c_test/" --model cfg/tiny-yolo-voc-3c.cfg --load -1
