# %%
import cv2
from darkflow.net.build import TFNet
import numpy as np
import time
from time import time as timer

import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'
# Out:
# /home/cfchen/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /home/cfchen/anaconda3/envs/py35/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
option = {
    'model': 'cfg/tiny-yolo-voc-3c.cfg',
    'load': '/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/YOLO-WEIGHTS/tiny-yolo-voc.weights',
    'dataset': '/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/data3c1c/3CBenzVWAUDI/MY20173c/JPEGImages',
    'annotation': '/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/data3c1c/3CBenzVWAUDI/MY20173c/Annotations',
    'lr': 0.001,
    'epoch': 20,
    'trainer': 'adam',
    'gpu': 0.85
}

# %%
# !./flow --model cfg/tiny-yolo-voc-3c.cfg --train --dataset "/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/data3c1c/3CBenzVWAUDI/MY20173c/JPEGImages" --annotation "/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/data3c1c/3CBenzVWAUDI/MY20173c/Annotations" --gpu 0.9 --epoch 100 --trainer adam --load /media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/YOLO-WEIGHTS/tiny-yolo-voc.weights --lr 0.001
# Out:
# /home/cfchen/anaconda3/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /home/cfchen/anaconda3/envs/py35/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo-voc-3c.cfg
# Loading /media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/YOLO-WEIGHTS/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.0029582977294921875s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 40)
# -------+--------+----------------------------------+---------------
# GPU mode with 0.9 usage
# cfg/tiny-yolo-voc-3c.cfg loss hyper-parameters:
# 	H       = 13
# 	W       = 13
# 	box     = 5
# 	classes = 3
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# Building cfg/tiny-yolo-voc-3c.cfg loss
# Building cfg/tiny-yolo-voc-3c.cfg train op
# 2018-05-22 17:58:27.076569: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-05-22 17:58:27.174380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-05-22 17:58:27.174637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1344] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 9.85GiB
# 2018-05-22 17:58:27.174651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1423] Adding visible gpu devices: 0
# 2018-05-22 17:58:27.343489: I tensorflow/core/common_runtime/gpu/gpu_device.cc:911] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-05-22 17:58:27.343522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:917]      0
# 2018-05-22 17:58:27.343529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:930] 0:   N
# 2018-05-22 17:58:27.343690: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1041] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10053 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2018-05-22 17:58:27.345219: E tensorflow/stream_executor/cuda/cuda_driver.cc:936] failed to allocate 9.82G (10542337024 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY
# Finished in 4.017284393310547s
#
# Enter training ...
#
# cfg/tiny-yolo-voc-3c.cfg parsing /media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/data3c1c/3CBenzVWAUDI/MY20173c/Annotations
# Parsing for ['benz', 'volkswagen', 'audi']
# [====================>]100%  022.xml
# Statistics:
# volkswagen: 10
# audi: 10
# benz: 10
# Dataset size: 30
# Dataset of 30 instance(s)
# Training statistics:
# 	Learning rate : 0.001
# 	Batch size    : 16
# 	Epoch number  : 100
# 	Backup every  : 2000
# step 1 - loss 100.00424194335938 - moving ave loss 100.00424194335938
# Finish 1 epoch(es)
# step 2 - loss 80.94857025146484 - moving ave loss 98.09867477416992
# Finish 2 epoch(es)
# step 3 - loss 57.38816833496094 - moving ave loss 94.02762413024902
# Finish 3 epoch(es)
# step 4 - loss 30.69150733947754 - moving ave loss 87.69401245117187
# Finish 4 epoch(es)
# step 5 - loss 17.095035552978516 - moving ave loss 80.63411476135255
# Finish 5 epoch(es)
# step 6 - loss 11.100130081176758 - moving ave loss 73.68071629333497
# Finish 6 epoch(es)
# step 7 - loss 7.286987781524658 - moving ave loss 67.04134344215393
# Finish 7 epoch(es)
# step 8 - loss 4.739256858825684 - moving ave loss 60.81113478382111
# Finish 8 epoch(es)
# step 9 - loss 3.8501782417297363 - moving ave loss 55.11503912961198
# Finish 9 epoch(es)
# step 10 - loss 3.1888527870178223 - moving ave loss 49.92242049535257
# Finish 10 epoch(es)
# step 11 - loss 2.686086654663086 - moving ave loss 45.19878711128362
# Finish 11 epoch(es)
# step 12 - loss 2.3513782024383545 - moving ave loss 40.914046220399094
# Finish 12 epoch(es)
# step 13 - loss 2.1129889488220215 - moving ave loss 37.03394049324139
# Finish 13 epoch(es)
# step 14 - loss 1.7629570960998535 - moving ave loss 33.50684215352724
# Finish 14 epoch(es)
# step 15 - loss 1.9041486978530884 - moving ave loss 30.346572807959824
# Finish 15 epoch(es)
# step 16 - loss 1.570852279663086 - moving ave loss 27.46900075513015
# Finish 16 epoch(es)
# step 17 - loss 1.5573656558990479 - moving ave loss 24.87783724520704
# Finish 17 epoch(es)
# step 18 - loss 1.3577172756195068 - moving ave loss 22.52582524824829
# Finish 18 epoch(es)
# step 19 - loss 1.3589372634887695 - moving ave loss 20.409136449772337
# Finish 19 epoch(es)
# step 20 - loss 1.5293618440628052 - moving ave loss 18.521158989201382
# Finish 20 epoch(es)
# step 21 - loss 2.1179075241088867 - moving ave loss 16.880833842692134
# Finish 21 epoch(es)
# step 22 - loss 1.5567736625671387 - moving ave loss 15.348427824679636
# Finish 22 epoch(es)
# step 23 - loss 1.4151346683502197 - moving ave loss 13.955098509046694
# Finish 23 epoch(es)
# step 24 - loss 1.9279770851135254 - moving ave loss 12.752386366653377
# Finish 24 epoch(es)
# step 25 - loss 1.4432250261306763 - moving ave loss 11.621470232601109
# Finish 25 epoch(es)
# step 26 - loss 1.553910493850708 - moving ave loss 10.614714258726067
# Finish 26 epoch(es)
# step 27 - loss 1.5341718196868896 - moving ave loss 9.70666001482215
# Finish 27 epoch(es)
# step 28 - loss 1.163027286529541 - moving ave loss 8.85229674199289
# Finish 28 epoch(es)
# step 29 - loss 1.5294395685195923 - moving ave loss 8.12001102464556
# Finish 29 epoch(es)
# step 30 - loss 1.2138783931732178 - moving ave loss 7.429397761498326
# Finish 30 epoch(es)
# step 31 - loss 1.1325643062591553 - moving ave loss 6.799714415974409
# Finish 31 epoch(es)
# step 32 - loss 1.1487369537353516 - moving ave loss 6.234616669750504
# Finish 32 epoch(es)
# step 33 - loss 0.9914667010307312 - moving ave loss 5.7103016728785265
# Finish 33 epoch(es)
# step 34 - loss 1.1433489322662354 - moving ave loss 5.253606398817298
# Finish 34 epoch(es)
# step 35 - loss 1.3855936527252197 - moving ave loss 4.86680512420809
# Finish 35 epoch(es)
# step 36 - loss 1.788377285003662 - moving ave loss 4.558962340287648
# Finish 36 epoch(es)
# step 37 - loss 1.5944726467132568 - moving ave loss 4.262513370930209
# Finish 37 epoch(es)
# step 38 - loss 1.8655240535736084 - moving ave loss 4.0228144391945495
# Finish 38 epoch(es)
# step 39 - loss 1.7457835674285889 - moving ave loss 3.7951113520179534
# Finish 39 epoch(es)
# step 40 - loss 1.6704844236373901 - moving ave loss 3.5826486591798967
# Finish 40 epoch(es)
# step 41 - loss 1.4984865188598633 - moving ave loss 3.3742324451478938
# Finish 41 epoch(es)
# step 42 - loss 1.686853051185608 - moving ave loss 3.2054945057516653
# Finish 42 epoch(es)
# step 43 - loss 1.6624853610992432 - moving ave loss 3.0511935912864234
# Finish 43 epoch(es)
# step 44 - loss 1.4037683010101318 - moving ave loss 2.886451062258794
# Finish 44 epoch(es)
# step 45 - loss 1.9449048042297363 - moving ave loss 2.792296436455888
# Finish 45 epoch(es)
# step 46 - loss 1.5054490566253662 - moving ave loss 2.663611698472836
# Finish 46 epoch(es)
# step 47 - loss 1.4634253978729248 - moving ave loss 2.5435930684128447
# Finish 47 epoch(es)
# step 48 - loss 1.3261281251907349 - moving ave loss 2.4218465740906336
# Finish 48 epoch(es)
# step 49 - loss 1.64143967628479 - moving ave loss 2.3438058843100493
# Finish 49 epoch(es)
# step 50 - loss 1.4814022779464722 - moving ave loss 2.2575655236736916
# Finish 50 epoch(es)
# step 51 - loss 1.4838775396347046 - moving ave loss 2.1801967252697927
# Finish 51 epoch(es)
# step 52 - loss 1.362959384918213 - moving ave loss 2.098472991234635
# Finish 52 epoch(es)
# step 53 - loss 1.273840308189392 - moving ave loss 2.016009722930111
# Finish 53 epoch(es)
# step 54 - loss 1.5452852249145508 - moving ave loss 1.9689372731285548
# Finish 54 epoch(es)
# step 55 - loss 1.4826200008392334 - moving ave loss 1.9203055458996228
# Finish 55 epoch(es)
# step 56 - loss 1.213071584701538 - moving ave loss 1.8495821497798142
# Finish 56 epoch(es)
# step 57 - loss 1.2929816246032715 - moving ave loss 1.79392209726216
# Finish 57 epoch(es)
# step 58 - loss 1.3246231079101562 - moving ave loss 1.7469921983269596
# Finish 58 epoch(es)
# step 59 - loss 0.849524736404419 - moving ave loss 1.6572454521347055
# Finish 59 epoch(es)
# step 60 - loss 1.2189744710922241 - moving ave loss 1.6134183540304574
# Finish 60 epoch(es)
# step 61 - loss 1.040299415588379 - moving ave loss 1.5561064601862495
# Finish 61 epoch(es)
# step 62 - loss 1.0731887817382812 - moving ave loss 1.5078146923414528
# Finish 62 epoch(es)
# step 63 - loss 0.7766221165657043 - moving ave loss 1.434695434763878
# Finish 63 epoch(es)
# step 64 - loss 0.884278416633606 - moving ave loss 1.379653732950851
# Finish 64 epoch(es)
# step 65 - loss 0.5834829211235046 - moving ave loss 1.3000366517681163
# Finish 65 epoch(es)
# step 66 - loss 0.517376184463501 - moving ave loss 1.2217706050376549
# Finish 66 epoch(es)
# step 67 - loss 0.7686042189598083 - moving ave loss 1.17645396642987
# Finish 67 epoch(es)
# step 68 - loss 0.7357240915298462 - moving ave loss 1.1323809789398678
# Finish 68 epoch(es)
# step 69 - loss 0.674033522605896 - moving ave loss 1.0865462333064708
# Finish 69 epoch(es)
# step 70 - loss 0.6029098033905029 - moving ave loss 1.038182590314874
# Finish 70 epoch(es)
# step 71 - loss 0.5647706389427185 - moving ave loss 0.9908413951776586
# Finish 71 epoch(es)
# step 72 - loss 0.59037184715271 - moving ave loss 0.9507944403751637
# Finish 72 epoch(es)
# step 73 - loss 0.8258724212646484 - moving ave loss 0.9383022384641122
# Finish 73 epoch(es)
# step 74 - loss 0.6025758981704712 - moving ave loss 0.9047296044347481
# Finish 74 epoch(es)
# step 75 - loss 0.6912548542022705 - moving ave loss 0.8833821294115004
# Finish 75 epoch(es)
# step 76 - loss 0.7397212386131287 - moving ave loss 0.8690160403316632
# Finish 76 epoch(es)
# step 77 - loss 0.9194431304931641 - moving ave loss 0.8740587493478134
# Finish 77 epoch(es)
# step 78 - loss 0.526181697845459 - moving ave loss 0.8392710441975779
# Finish 78 epoch(es)
# step 79 - loss 1.0209686756134033 - moving ave loss 0.8574408073391604
# Finish 79 epoch(es)
# step 80 - loss 0.6655367612838745 - moving ave loss 0.8382504027336318
# Finish 80 epoch(es)
# step 81 - loss 0.6370440721511841 - moving ave loss 0.8181297696753871
# Finish 81 epoch(es)
# step 82 - loss 0.5754239559173584 - moving ave loss 0.7938591882995842
# Finish 82 epoch(es)
# step 83 - loss 0.5253422260284424 - moving ave loss 0.7670074920724701
# Finish 83 epoch(es)
# step 84 - loss 0.5828122496604919 - moving ave loss 0.7485879678312722
# Finish 84 epoch(es)
# step 85 - loss 0.6832443475723267 - moving ave loss 0.7420536058053777
# Finish 85 epoch(es)
# step 86 - loss 0.4610843360424042 - moving ave loss 0.7139566788290804
# Finish 86 epoch(es)
# step 87 - loss 0.41170185804367065 - moving ave loss 0.6837311967505394
# Finish 87 epoch(es)
# step 88 - loss 0.2303159236907959 - moving ave loss 0.6383896694445651
# Finish 88 epoch(es)
# step 89 - loss 0.4006238579750061 - moving ave loss 0.6146130882976093
# Finish 89 epoch(es)
# step 90 - loss 0.4439929723739624 - moving ave loss 0.5975510767052447
# Finish 90 epoch(es)
# step 91 - loss 0.3409202992916107 - moving ave loss 0.5718879989638812
# Finish 91 epoch(es)
# step 92 - loss 0.5820412039756775 - moving ave loss 0.5729033194650608
# Finish 92 epoch(es)
# step 93 - loss 0.5597401857376099 - moving ave loss 0.5715870060923157
# Finish 93 epoch(es)
# step 94 - loss 0.284778356552124 - moving ave loss 0.5429061411382966
# Finish 94 epoch(es)
# step 95 - loss 0.3799785375595093 - moving ave loss 0.5266133807804179
# Finish 95 epoch(es)
# step 96 - loss 0.4570114016532898 - moving ave loss 0.519653182867705
# Finish 96 epoch(es)
# step 97 - loss 0.21773578226566315 - moving ave loss 0.48946144280750087
# Finish 97 epoch(es)
# step 98 - loss 0.4351108968257904 - moving ave loss 0.48402638820932986
# Finish 98 epoch(es)
# step 99 - loss 0.35201069712638855 - moving ave loss 0.47082481910103574
# Finish 99 epoch(es)
# step 100 - loss 0.2522161900997162 - moving ave loss 0.4489639562009038
# Finish 100 epoch(es)
# Checkpoint at step 100
# Training finished, exit.
