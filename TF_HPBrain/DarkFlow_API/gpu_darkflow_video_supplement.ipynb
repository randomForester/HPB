# %%
import cv2
from darkflow.net.build import TFNet
import numpy as np
import time
from time import time as timer

import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg'

# %%
option = {
    'model': 'cfg/yolo.cfg',
    'load': 'bin/yolo.weights',
    'threshold': 0.25,
    'gpu': 0.85
}

tfnet = TFNet(option)
# Out:
# Parsing ./cfg/yolo.cfg
# Parsing cfg/yolo.cfg
# Loading bin/yolo.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.05769491195678711s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 76, 76, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 38, 38, 512)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 19, 19, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | concat [16]                      | (?, 38, 38, 512)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 38, 38, 64)
#  Load  |  Yep!  | local flatten 2x2                | (?, 19, 19, 256)
#  Load  |  Yep!  | concat [27, 24]                  | (?, 19, 19, 1280)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 19, 19, 1024)
#  Load  |  Yep!  | conv 1x1p0_1    linear           | (?, 19, 19, 425)
# -------+--------+----------------------------------+---------------
# GPU mode with 0.85 usage
# Finished in 7.621327638626099s

# %%
capture = cv2.VideoCapture('/media/cfchen/956df7bc-562e-4f24-8339-fd0b67f98888/Downloaded/VideosHPB/HPB_1.mp4')
#capture = cv2.VideoCapture('../VideosHPB/IMAG0011.mp4')
colors = [tuple(255 * np.random.rand(3)) for i in range(5)]  #range(100)

# %%
for color in colors:
    print(color)
# Out:
# (180.40594487543515, 8.819560767489666, 169.60596932308064)
# (242.95166112587353, 223.42415552573, 82.31899184507752)
# (97.38613081973283, 35.14039210742239, 200.5663209724577)
# (46.00505798206131, 222.92091359733854, 233.09145293674044)
# (182.51801591640464, 56.97540305074199, 142.07853795947753)

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc, 30.0, (1920,1080))

# %% [markdown]
# ## Pre-process (a)

# %%
count = 0
while(True):
    stime = time.time()
    ret, frame = capture.read()

    if ret == False:
        break;
    else:
        count = count + 1

    # B & W image (using red channel only)
    #frame = np.stack((frame[:,:,0],frame[:,:,0],frame[:,:,0]),axis=2)
    results = tfnet.return_predict(frame)
    #print(results)

    if ret:
        for color, result in zip(colors, results):
            tl = (result['topleft']['x'], result['topleft']['y'])
            br = (result['bottomright']['x'], result['bottomright']['y'])
            brX = result['bottomright']['x']
            brY = result['bottomright']['y']
            label = result['label']
            confidence = result['confidence']
            confidence = round(confidence, 1)
            frame = cv2.rectangle(frame, tl, br, color, 7)
            #frame = cv2.putText(frame, label, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
            frame = cv2.putText(frame, label, (brX - 50, brY + 20), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
            frame = cv2.putText(frame, str(confidence), tl, cv2.FONT_HERSHEY_COMPLEX, 0.65, (0, 255, 0), 2)

        out.write(frame)
        cv2.imshow('frame', frame)
        #
        print("Shape of Frame: {}".format(frame.shape))
        print("Type of Frame:  {}".format(type(frame)))
        print("Results:        {}".format(result))
        print('FPS         {:.1f}'.format(1 / (time.time() - stime)))  # Frame per seconds
        #
        if (cv2.waitKey(1) & 0xFF == ord('q')) or (ret == False):
            break

print('++++++++ Video End ++++++++')
  
capture.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1858, 'y': 740}, 'label': 'car', 'confidence': 0.5496255, 'topleft': {'x': 1732, 'y': 652}}
# FPS         13.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1847, 'y': 736}, 'label': 'car', 'confidence': 0.5003806, 'topleft': {'x': 1723, 'y': 652}}
# FPS         20.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.35934627, 'topleft': {'x': 154, 'y': 671}}
# FPS         21.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 317, 'y': 756}, 'label': 'car', 'confidence': 0.3566666, 'topleft': {'x': 155, 'y': 671}}
# FPS         21.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1845, 'y': 738}, 'label': 'car', 'confidence': 0.43599457, 'topleft': {'x': 1710, 'y': 651}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1841, 'y': 736}, 'label': 'car', 'confidence': 0.47197005, 'topleft': {'x': 1705, 'y': 650}}
# FPS         21.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1851, 'y': 733}, 'label': 'car', 'confidence': 0.49220586, 'topleft': {'x': 1768, 'y': 652}}
# FPS         21.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1843, 'y': 732}, 'label': 'car', 'confidence': 0.48000702, 'topleft': {'x': 1712, 'y': 647}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1838, 'y': 736}, 'label': 'car', 'confidence': 0.46757942, 'topleft': {'x': 1703, 'y': 644}}
# FPS         21.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.46321473, 'topleft': {'x': 185, 'y': 724}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 352, 'y': 810}, 'label': 'car', 'confidence': 0.46236295, 'topleft': {'x': 185, 'y': 724}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 355, 'y': 810}, 'label': 'car', 'confidence': 0.461087, 'topleft': {'x': 187, 'y': 724}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.4525719, 'topleft': {'x': 187, 'y': 723}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 351, 'y': 809}, 'label': 'car', 'confidence': 0.44786584, 'topleft': {'x': 187, 'y': 723}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 355, 'y': 809}, 'label': 'car', 'confidence': 0.46960124, 'topleft': {'x': 188, 'y': 723}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.47036558, 'topleft': {'x': 190, 'y': 723}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 354, 'y': 810}, 'label': 'car', 'confidence': 0.48498204, 'topleft': {'x': 189, 'y': 724}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 753}, 'label': 'car', 'confidence': 0.35268015, 'topleft': {'x': 155, 'y': 669}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.3574199, 'topleft': {'x': 153, 'y': 668}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 754}, 'label': 'car', 'confidence': 0.36536786, 'topleft': {'x': 153, 'y': 669}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.35818538, 'topleft': {'x': 153, 'y': 669}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.34808204, 'topleft': {'x': 155, 'y': 668}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 753}, 'label': 'car', 'confidence': 0.37836057, 'topleft': {'x': 152, 'y': 671}}
# FPS         21.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 353, 'y': 810}, 'label': 'car', 'confidence': 0.47286704, 'topleft': {'x': 188, 'y': 724}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 313, 'y': 755}, 'label': 'car', 'confidence': 0.36571833, 'topleft': {'x': 152, 'y': 671}}
# FPS         21.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 313, 'y': 755}, 'label': 'car', 'confidence': 0.3587551, 'topleft': {'x': 154, 'y': 671}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 754}, 'label': 'car', 'confidence': 0.38373753, 'topleft': {'x': 152, 'y': 672}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 754}, 'label': 'car', 'confidence': 0.36015517, 'topleft': {'x': 154, 'y': 672}}
# FPS         24.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1715, 'y': 695}, 'label': 'car', 'confidence': 0.6862192, 'topleft': {'x': 1541, 'y': 609}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1711, 'y': 694}, 'label': 'car', 'confidence': 0.6684057, 'topleft': {'x': 1536, 'y': 602}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1707, 'y': 693}, 'label': 'car', 'confidence': 0.75103354, 'topleft': {'x': 1504, 'y': 603}}
# FPS         19.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1701, 'y': 691}, 'label': 'car', 'confidence': 0.76405025, 'topleft': {'x': 1503, 'y': 603}}
# FPS         19.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1697, 'y': 688}, 'label': 'car', 'confidence': 0.7837072, 'topleft': {'x': 1502, 'y': 602}}
# FPS         20.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1697, 'y': 685}, 'label': 'car', 'confidence': 0.798151, 'topleft': {'x': 1493, 'y': 600}}
# FPS         20.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1680, 'y': 686}, 'label': 'car', 'confidence': 0.76801544, 'topleft': {'x': 1477, 'y': 594}}
# FPS         18.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1668, 'y': 686}, 'label': 'car', 'confidence': 0.7754165, 'topleft': {'x': 1461, 'y': 593}}
# FPS         18.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 659}, 'label': 'car', 'confidence': 0.32407546, 'topleft': {'x': 1714, 'y': 605}}
# FPS         18.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.35090208, 'topleft': {'x': 153, 'y': 670}}
# FPS         18.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 754}, 'label': 'car', 'confidence': 0.33430067, 'topleft': {'x': 156, 'y': 672}}
# FPS         17.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 754}, 'label': 'car', 'confidence': 0.31583342, 'topleft': {'x': 156, 'y': 670}}
# FPS         21.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1909, 'y': 757}, 'label': 'car', 'confidence': 0.38635278, 'topleft': {'x': 1844, 'y': 681}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 317, 'y': 754}, 'label': 'car', 'confidence': 0.30111906, 'topleft': {'x': 158, 'y': 670}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1908, 'y': 769}, 'label': 'car', 'confidence': 0.43397245, 'topleft': {'x': 1807, 'y': 669}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 754}, 'label': 'car', 'confidence': 0.3047316, 'topleft': {'x': 156, 'y': 671}}
# FPS         17.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 318, 'y': 754}, 'label': 'car', 'confidence': 0.30830666, 'topleft': {'x': 159, 'y': 671}}
# FPS         19.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 318, 'y': 755}, 'label': 'car', 'confidence': 0.32174087, 'topleft': {'x': 158, 'y': 671}}
# FPS         19.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 756}, 'label': 'car', 'confidence': 0.34235263, 'topleft': {'x': 155, 'y': 672}}
# FPS         18.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 665}, 'label': 'car', 'confidence': 0.34822088, 'topleft': {'x': 1716, 'y': 605}}
# FPS         19.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 640}, 'label': 'car', 'confidence': 0.51892304, 'topleft': {'x': 1695, 'y': 582}}
# FPS         20.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1791, 'y': 653}, 'label': 'car', 'confidence': 0.5016251, 'topleft': {'x': 1681, 'y': 582}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 665}, 'label': 'car', 'confidence': 0.2506548, 'topleft': {'x': 1720, 'y': 606}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 756}, 'label': 'car', 'confidence': 0.3498526, 'topleft': {'x': 155, 'y': 672}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 757}, 'label': 'car', 'confidence': 0.35261637, 'topleft': {'x': 156, 'y': 672}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 311, 'y': 757}, 'label': 'car', 'confidence': 0.36118758, 'topleft': {'x': 156, 'y': 672}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 313, 'y': 757}, 'label': 'car', 'confidence': 0.3696838, 'topleft': {'x': 151, 'y': 673}}
# FPS         21.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1804, 'y': 683}, 'label': 'car', 'confidence': 0.2530299, 'topleft': {'x': 1688, 'y': 594}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1800, 'y': 685}, 'label': 'car', 'confidence': 0.2620812, 'topleft': {'x': 1688, 'y': 592}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1788, 'y': 639}, 'label': 'car', 'confidence': 0.55968726, 'topleft': {'x': 1690, 'y': 580}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 639}, 'label': 'car', 'confidence': 0.55572885, 'topleft': {'x': 1690, 'y': 580}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 640}, 'label': 'car', 'confidence': 0.56533813, 'topleft': {'x': 1689, 'y': 581}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1788, 'y': 640}, 'label': 'car', 'confidence': 0.56077063, 'topleft': {'x': 1687, 'y': 581}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 640}, 'label': 'car', 'confidence': 0.5660621, 'topleft': {'x': 1687, 'y': 581}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 642}, 'label': 'car', 'confidence': 0.5959505, 'topleft': {'x': 1688, 'y': 581}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 640}, 'label': 'car', 'confidence': 0.62154186, 'topleft': {'x': 1686, 'y': 581}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 639}, 'label': 'car', 'confidence': 0.6196815, 'topleft': {'x': 1687, 'y': 580}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 641}, 'label': 'car', 'confidence': 0.63193053, 'topleft': {'x': 1686, 'y': 580}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1818, 'y': 698}, 'label': 'car', 'confidence': 0.3271324, 'topleft': {'x': 1706, 'y': 596}}
# FPS         24.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1812, 'y': 699}, 'label': 'car', 'confidence': 0.3492582, 'topleft': {'x': 1705, 'y': 596}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 640}, 'label': 'car', 'confidence': 0.62585384, 'topleft': {'x': 1684, 'y': 578}}
# FPS         20.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1821, 'y': 703}, 'label': 'car', 'confidence': 0.32126057, 'topleft': {'x': 1708, 'y': 595}}
# FPS         20.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1790, 'y': 641}, 'label': 'car', 'confidence': 0.57024586, 'topleft': {'x': 1691, 'y': 581}}
# FPS         20.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1835, 'y': 702}, 'label': 'car', 'confidence': 0.33990762, 'topleft': {'x': 1712, 'y': 597}}
# FPS         21.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1829, 'y': 707}, 'label': 'car', 'confidence': 0.35152608, 'topleft': {'x': 1710, 'y': 597}}
# FPS         19.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1788, 'y': 639}, 'label': 'car', 'confidence': 0.566036, 'topleft': {'x': 1689, 'y': 579}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1830, 'y': 712}, 'label': 'car', 'confidence': 0.35679823, 'topleft': {'x': 1710, 'y': 598}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1827, 'y': 714}, 'label': 'car', 'confidence': 0.35502595, 'topleft': {'x': 1706, 'y': 598}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 642}, 'label': 'car', 'confidence': 0.61500067, 'topleft': {'x': 1685, 'y': 580}}
# FPS         19.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1788, 'y': 642}, 'label': 'car', 'confidence': 0.6095522, 'topleft': {'x': 1685, 'y': 580}}
# FPS         21.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1789, 'y': 643}, 'label': 'car', 'confidence': 0.6326528, 'topleft': {'x': 1686, 'y': 581}}
# FPS         19.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 643}, 'label': 'car', 'confidence': 0.60848933, 'topleft': {'x': 1688, 'y': 581}}
# FPS         20.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1788, 'y': 643}, 'label': 'car', 'confidence': 0.5975927, 'topleft': {'x': 1688, 'y': 581}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 318, 'y': 754}, 'label': 'car', 'confidence': 0.32279453, 'topleft': {'x': 152, 'y': 670}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1820, 'y': 715}, 'label': 'car', 'confidence': 0.34830093, 'topleft': {'x': 1695, 'y': 602}}
# FPS         20.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1815, 'y': 715}, 'label': 'car', 'confidence': 0.34513503, 'topleft': {'x': 1696, 'y': 602}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1786, 'y': 638}, 'label': 'car', 'confidence': 0.475678, 'topleft': {'x': 1696, 'y': 581}}
# FPS         19.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1787, 'y': 639}, 'label': 'car', 'confidence': 0.5154071, 'topleft': {'x': 1693, 'y': 581}}
# FPS         21.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.34182778, 'topleft': {'x': 149, 'y': 669}}
# FPS         20.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 754}, 'label': 'car', 'confidence': 0.34580475, 'topleft': {'x': 151, 'y': 670}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1815, 'y': 717}, 'label': 'car', 'confidence': 0.3596817, 'topleft': {'x': 1684, 'y': 600}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1813, 'y': 717}, 'label': 'car', 'confidence': 0.3580276, 'topleft': {'x': 1686, 'y': 601}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1805, 'y': 741}, 'label': 'car', 'confidence': 0.45269036, 'topleft': {'x': 1679, 'y': 645}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 317, 'y': 755}, 'label': 'car', 'confidence': 0.34529835, 'topleft': {'x': 153, 'y': 669}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 317, 'y': 755}, 'label': 'car', 'confidence': 0.35376766, 'topleft': {'x': 152, 'y': 669}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.34564227, 'topleft': {'x': 152, 'y': 668}}
# FPS         23.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1784, 'y': 636}, 'label': 'car', 'confidence': 0.61021465, 'topleft': {'x': 1679, 'y': 581}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1783, 'y': 635}, 'label': 'car', 'confidence': 0.62416327, 'topleft': {'x': 1679, 'y': 582}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1781, 'y': 637}, 'label': 'car', 'confidence': 0.64681196, 'topleft': {'x': 1681, 'y': 582}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1781, 'y': 637}, 'label': 'car', 'confidence': 0.64578706, 'topleft': {'x': 1681, 'y': 581}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1783, 'y': 636}, 'label': 'car', 'confidence': 0.65243757, 'topleft': {'x': 1680, 'y': 583}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1784, 'y': 638}, 'label': 'car', 'confidence': 0.630035, 'topleft': {'x': 1682, 'y': 583}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1782, 'y': 640}, 'label': 'car', 'confidence': 0.6769226, 'topleft': {'x': 1677, 'y': 585}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 313, 'y': 754}, 'label': 'car', 'confidence': 0.4015491, 'topleft': {'x': 153, 'y': 670}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1785, 'y': 739}, 'label': 'car', 'confidence': 0.6605736, 'topleft': {'x': 1624, 'y': 644}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1784, 'y': 738}, 'label': 'car', 'confidence': 0.66498446, 'topleft': {'x': 1622, 'y': 643}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 752}, 'label': 'car', 'confidence': 0.39734384, 'topleft': {'x': 151, 'y': 668}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.39771497, 'topleft': {'x': 150, 'y': 669}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.4763495, 'topleft': {'x': 184, 'y': 724}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1784, 'y': 740}, 'label': 'car', 'confidence': 0.7137171, 'topleft': {'x': 1613, 'y': 639}}
# FPS         18.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 353, 'y': 808}, 'label': 'car', 'confidence': 0.48586103, 'topleft': {'x': 183, 'y': 724}}
# FPS         20.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1780, 'y': 690}, 'label': 'car', 'confidence': 0.28980166, 'topleft': {'x': 1680, 'y': 590}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 355, 'y': 809}, 'label': 'car', 'confidence': 0.48211926, 'topleft': {'x': 186, 'y': 724}}
# FPS         19.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 354, 'y': 810}, 'label': 'car', 'confidence': 0.4891712, 'topleft': {'x': 187, 'y': 724}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1776, 'y': 743}, 'label': 'car', 'confidence': 0.7253181, 'topleft': {'x': 1600, 'y': 644}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1772, 'y': 744}, 'label': 'car', 'confidence': 0.72484493, 'topleft': {'x': 1602, 'y': 643}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 752}, 'label': 'car', 'confidence': 0.37857455, 'topleft': {'x': 154, 'y': 668}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 752}, 'label': 'car', 'confidence': 0.3668285, 'topleft': {'x': 155, 'y': 668}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 753}, 'label': 'car', 'confidence': 0.37699783, 'topleft': {'x': 154, 'y': 669}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1773, 'y': 746}, 'label': 'car', 'confidence': 0.71640027, 'topleft': {'x': 1598, 'y': 647}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1765, 'y': 748}, 'label': 'car', 'confidence': 0.7110895, 'topleft': {'x': 1602, 'y': 648}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 752}, 'label': 'car', 'confidence': 0.38885945, 'topleft': {'x': 148, 'y': 669}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 753}, 'label': 'car', 'confidence': 0.36125538, 'topleft': {'x': 150, 'y': 669}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1790, 'y': 653}, 'label': 'car', 'confidence': 0.56595063, 'topleft': {'x': 1675, 'y': 584}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1790, 'y': 652}, 'label': 'car', 'confidence': 0.6093347, 'topleft': {'x': 1674, 'y': 586}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1771, 'y': 633}, 'label': 'car', 'confidence': 0.25547904, 'topleft': {'x': 1706, 'y': 581}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 652}, 'label': 'car', 'confidence': 0.6069102, 'topleft': {'x': 1673, 'y': 586}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 653}, 'label': 'car', 'confidence': 0.61852723, 'topleft': {'x': 1671, 'y': 586}}
# FPS         24.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 653}, 'label': 'car', 'confidence': 0.64736354, 'topleft': {'x': 1671, 'y': 584}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 753}, 'label': 'car', 'confidence': 0.3808502, 'topleft': {'x': 149, 'y': 669}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1742, 'y': 761}, 'label': 'car', 'confidence': 0.58601296, 'topleft': {'x': 1599, 'y': 653}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 754}, 'label': 'car', 'confidence': 0.3293438, 'topleft': {'x': 152, 'y': 668}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 753}, 'label': 'car', 'confidence': 0.37530488, 'topleft': {'x': 149, 'y': 669}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1739, 'y': 769}, 'label': 'car', 'confidence': 0.6123527, 'topleft': {'x': 1596, 'y': 654}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1734, 'y': 770}, 'label': 'car', 'confidence': 0.56515366, 'topleft': {'x': 1597, 'y': 651}}
# FPS         21.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1737, 'y': 771}, 'label': 'car', 'confidence': 0.53822875, 'topleft': {'x': 1601, 'y': 646}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1798, 'y': 653}, 'label': 'car', 'confidence': 0.60342616, 'topleft': {'x': 1669, 'y': 582}}
# FPS         20.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1799, 'y': 653}, 'label': 'car', 'confidence': 0.6280837, 'topleft': {'x': 1668, 'y': 584}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1798, 'y': 654}, 'label': 'car', 'confidence': 0.6055384, 'topleft': {'x': 1668, 'y': 584}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1799, 'y': 653}, 'label': 'car', 'confidence': 0.56236374, 'topleft': {'x': 1672, 'y': 584}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 313, 'y': 753}, 'label': 'car', 'confidence': 0.37190506, 'topleft': {'x': 152, 'y': 668}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1797, 'y': 652}, 'label': 'car', 'confidence': 0.5324387, 'topleft': {'x': 1671, 'y': 585}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 653}, 'label': 'car', 'confidence': 0.50966316, 'topleft': {'x': 1673, 'y': 584}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 652}, 'label': 'car', 'confidence': 0.49146152, 'topleft': {'x': 1673, 'y': 583}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1776, 'y': 632}, 'label': 'car', 'confidence': 0.25475782, 'topleft': {'x': 1710, 'y': 582}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 324, 'y': 495}, 'label': 'car', 'confidence': 0.7841223, 'topleft': {'x': 172, 'y': 436}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 300, 'y': 494}, 'label': 'car', 'confidence': 0.7586776, 'topleft': {'x': 158, 'y': 437}}
# FPS         21.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 653}, 'label': 'car', 'confidence': 0.44487837, 'topleft': {'x': 1674, 'y': 582}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 653}, 'label': 'car', 'confidence': 0.438193, 'topleft': {'x': 1676, 'y': 581}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1797, 'y': 653}, 'label': 'car', 'confidence': 0.4492832, 'topleft': {'x': 1676, 'y': 582}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1798, 'y': 654}, 'label': 'car', 'confidence': 0.47546783, 'topleft': {'x': 1675, 'y': 582}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1780, 'y': 634}, 'label': 'car', 'confidence': 0.30806574, 'topleft': {'x': 1709, 'y': 583}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 655}, 'label': 'car', 'confidence': 0.6105743, 'topleft': {'x': 1670, 'y': 581}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 655}, 'label': 'car', 'confidence': 0.6077339, 'topleft': {'x': 1670, 'y': 581}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 656}, 'label': 'car', 'confidence': 0.61349577, 'topleft': {'x': 1670, 'y': 581}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 345, 'y': 811}, 'label': 'car', 'confidence': 0.45381713, 'topleft': {'x': 185, 'y': 721}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 655}, 'label': 'car', 'confidence': 0.57394725, 'topleft': {'x': 1670, 'y': 580}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 655}, 'label': 'car', 'confidence': 0.5682835, 'topleft': {'x': 1671, 'y': 582}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 756}, 'label': 'car', 'confidence': 0.35688332, 'topleft': {'x': 154, 'y': 668}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 655}, 'label': 'car', 'confidence': 0.56241244, 'topleft': {'x': 1670, 'y': 582}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 654}, 'label': 'car', 'confidence': 0.5695076, 'topleft': {'x': 1669, 'y': 583}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 171, 'y': 499}, 'label': 'car', 'confidence': 0.5726129, 'topleft': {'x': 77, 'y': 445}}
# FPS         21.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 117, 'y': 510}, 'label': 'car', 'confidence': 0.3395463, 'topleft': {'x': 38, 'y': 463}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 137, 'y': 511}, 'label': 'car', 'confidence': 0.5344528, 'topleft': {'x': 39, 'y': 459}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 139, 'y': 510}, 'label': 'car', 'confidence': 0.58804727, 'topleft': {'x': 42, 'y': 453}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 140, 'y': 512}, 'label': 'car', 'confidence': 0.57062036, 'topleft': {'x': 40, 'y': 456}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 140, 'y': 510}, 'label': 'car', 'confidence': 0.68637043, 'topleft': {'x': 35, 'y': 452}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 133, 'y': 511}, 'label': 'car', 'confidence': 0.58772033, 'topleft': {'x': 40, 'y': 453}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 120, 'y': 511}, 'label': 'car', 'confidence': 0.5186412, 'topleft': {'x': 40, 'y': 456}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 106, 'y': 509}, 'label': 'car', 'confidence': 0.31555146, 'topleft': {'x': 36, 'y': 454}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 97, 'y': 514}, 'label': 'car', 'confidence': 0.34495112, 'topleft': {'x': 29, 'y': 453}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 88, 'y': 511}, 'label': 'car', 'confidence': 0.26347262, 'topleft': {'x': 24, 'y': 455}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 655}, 'label': 'car', 'confidence': 0.59391534, 'topleft': {'x': 1668, 'y': 584}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 654}, 'label': 'car', 'confidence': 0.5829069, 'topleft': {'x': 1669, 'y': 584}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 654}, 'label': 'car', 'confidence': 0.5895716, 'topleft': {'x': 1670, 'y': 584}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 66, 'y': 511}, 'label': 'car', 'confidence': 0.27543065, 'topleft': {'x': 16, 'y': 458}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 654}, 'label': 'car', 'confidence': 0.57682973, 'topleft': {'x': 1670, 'y': 584}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 654}, 'label': 'car', 'confidence': 0.57695067, 'topleft': {'x': 1669, 'y': 584}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 654}, 'label': 'car', 'confidence': 0.59386593, 'topleft': {'x': 1669, 'y': 584}}
# FPS         24.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 654}, 'label': 'car', 'confidence': 0.5721343, 'topleft': {'x': 1670, 'y': 584}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 653}, 'label': 'car', 'confidence': 0.5590327, 'topleft': {'x': 1671, 'y': 584}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 654}, 'label': 'car', 'confidence': 0.5681498, 'topleft': {'x': 1670, 'y': 584}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 653}, 'label': 'car', 'confidence': 0.56892645, 'topleft': {'x': 1670, 'y': 585}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 653}, 'label': 'car', 'confidence': 0.5986535, 'topleft': {'x': 1669, 'y': 585}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 655}, 'label': 'car', 'confidence': 0.5832712, 'topleft': {'x': 1668, 'y': 585}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 347, 'y': 811}, 'label': 'car', 'confidence': 0.46344617, 'topleft': {'x': 186, 'y': 721}}
# FPS         21.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 346, 'y': 812}, 'label': 'car', 'confidence': 0.4736617, 'topleft': {'x': 186, 'y': 721}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 405, 'y': 815}, 'label': 'car', 'confidence': 0.4054836, 'topleft': {'x': 251, 'y': 733}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 346, 'y': 812}, 'label': 'car', 'confidence': 0.47042468, 'topleft': {'x': 185, 'y': 721}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 346, 'y': 811}, 'label': 'car', 'confidence': 0.47095388, 'topleft': {'x': 186, 'y': 722}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 347, 'y': 811}, 'label': 'car', 'confidence': 0.47392672, 'topleft': {'x': 185, 'y': 721}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 347, 'y': 811}, 'label': 'car', 'confidence': 0.47034153, 'topleft': {'x': 186, 'y': 721}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.46797773, 'topleft': {'x': 185, 'y': 721}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 756}, 'label': 'car', 'confidence': 0.33126315, 'topleft': {'x': 157, 'y': 669}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 352, 'y': 811}, 'label': 'car', 'confidence': 0.4628025, 'topleft': {'x': 185, 'y': 722}}
# FPS         22.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 756}, 'label': 'car', 'confidence': 0.339757, 'topleft': {'x': 155, 'y': 669}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 350, 'y': 811}, 'label': 'car', 'confidence': 0.46971294, 'topleft': {'x': 185, 'y': 721}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 349, 'y': 811}, 'label': 'car', 'confidence': 0.47606847, 'topleft': {'x': 185, 'y': 721}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1919, 'y': 745}, 'label': 'car', 'confidence': 0.3129139, 'topleft': {'x': 1900, 'y': 676}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1919, 'y': 748}, 'label': 'car', 'confidence': 0.25203684, 'topleft': {'x': 1892, 'y': 673}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1919, 'y': 753}, 'label': 'car', 'confidence': 0.43995306, 'topleft': {'x': 1878, 'y': 670}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1916, 'y': 748}, 'label': 'car', 'confidence': 0.42687592, 'topleft': {'x': 1867, 'y': 659}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 312, 'y': 757}, 'label': 'car', 'confidence': 0.34268606, 'topleft': {'x': 155, 'y': 669}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1911, 'y': 741}, 'label': 'car', 'confidence': 0.45267195, 'topleft': {'x': 1848, 'y': 652}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 316, 'y': 757}, 'label': 'car', 'confidence': 0.32636106, 'topleft': {'x': 154, 'y': 670}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 315, 'y': 757}, 'label': 'car', 'confidence': 0.31039032, 'topleft': {'x': 155, 'y': 669}}
# FPS         23.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1917, 'y': 752}, 'label': 'car', 'confidence': 0.6726765, 'topleft': {'x': 1806, 'y': 658}}
# FPS         21.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1906, 'y': 753}, 'label': 'car', 'confidence': 0.6443936, 'topleft': {'x': 1784, 'y': 654}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1902, 'y': 752}, 'label': 'car', 'confidence': 0.6369056, 'topleft': {'x': 1776, 'y': 655}}
# FPS         22.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1904, 'y': 753}, 'label': 'car', 'confidence': 0.61284757, 'topleft': {'x': 1771, 'y': 655}}
# FPS         23.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1900, 'y': 756}, 'label': 'car', 'confidence': 0.60892344, 'topleft': {'x': 1770, 'y': 650}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1898, 'y': 754}, 'label': 'car', 'confidence': 0.56908625, 'topleft': {'x': 1760, 'y': 650}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 314, 'y': 754}, 'label': 'car', 'confidence': 0.35057375, 'topleft': {'x': 152, 'y': 670}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1830, 'y': 718}, 'label': 'car', 'confidence': 0.46823233, 'topleft': {'x': 1688, 'y': 591}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1799, 'y': 658}, 'label': 'car', 'confidence': 0.3041805, 'topleft': {'x': 1674, 'y': 577}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1829, 'y': 720}, 'label': 'car', 'confidence': 0.6035941, 'topleft': {'x': 1679, 'y': 597}}
# FPS         24.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 623}, 'label': 'car', 'confidence': 0.31051004, 'topleft': {'x': 1703, 'y': 579}}
# FPS         21.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1799, 'y': 721}, 'label': 'car', 'confidence': 0.72538346, 'topleft': {'x': 1655, 'y': 594}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1794, 'y': 714}, 'label': 'car', 'confidence': 0.68561643, 'topleft': {'x': 1650, 'y': 595}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1773, 'y': 619}, 'label': 'car', 'confidence': 0.3231496, 'topleft': {'x': 1705, 'y': 575}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1799, 'y': 701}, 'label': 'car', 'confidence': 0.7276555, 'topleft': {'x': 1602, 'y': 594}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# ...
# Results:        {'bottomright': {'x': 1230, 'y': 424}, 'label': 'car', 'confidence': 0.62237567, 'topleft': {'x': 1166, 'y': 388}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1233, 'y': 424}, 'label': 'car', 'confidence': 0.67658335, 'topleft': {'x': 1167, 'y': 388}}
# FPS         22.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1230, 'y': 424}, 'label': 'car', 'confidence': 0.6201828, 'topleft': {'x': 1165, 'y': 387}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1231, 'y': 424}, 'label': 'car', 'confidence': 0.6389752, 'topleft': {'x': 1166, 'y': 388}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1232, 'y': 424}, 'label': 'car', 'confidence': 0.65636927, 'topleft': {'x': 1170, 'y': 388}}
# FPS         21.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1232, 'y': 424}, 'label': 'car', 'confidence': 0.662665, 'topleft': {'x': 1174, 'y': 388}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1234, 'y': 422}, 'label': 'car', 'confidence': 0.6909371, 'topleft': {'x': 1174, 'y': 389}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1236, 'y': 423}, 'label': 'car', 'confidence': 0.6890712, 'topleft': {'x': 1173, 'y': 389}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1236, 'y': 423}, 'label': 'car', 'confidence': 0.70583415, 'topleft': {'x': 1177, 'y': 388}}
# FPS         24.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1236, 'y': 423}, 'label': 'car', 'confidence': 0.6980615, 'topleft': {'x': 1178, 'y': 389}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1233, 'y': 421}, 'label': 'car', 'confidence': 0.56654465, 'topleft': {'x': 1181, 'y': 389}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1233, 'y': 421}, 'label': 'car', 'confidence': 0.516073, 'topleft': {'x': 1181, 'y': 390}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1227, 'y': 419}, 'label': 'car', 'confidence': 0.36805022, 'topleft': {'x': 1176, 'y': 390}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1228, 'y': 421}, 'label': 'car', 'confidence': 0.34752813, 'topleft': {'x': 1178, 'y': 390}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1250, 'y': 420}, 'label': 'car', 'confidence': 0.39031145, 'topleft': {'x': 1210, 'y': 394}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1251, 'y': 419}, 'label': 'car', 'confidence': 0.41642454, 'topleft': {'x': 1211, 'y': 394}}
# FPS         21.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1251, 'y': 418}, 'label': 'car', 'confidence': 0.5171488, 'topleft': {'x': 1207, 'y': 392}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 635}, 'label': 'car', 'confidence': 0.31219542, 'topleft': {'x': 1705, 'y': 578}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1397, 'y': 436}, 'label': 'car', 'confidence': 0.26830053, 'topleft': {'x': 1361, 'y': 409}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 655}, 'label': 'car', 'confidence': 0.3796296, 'topleft': {'x': 1670, 'y': 583}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1399, 'y': 436}, 'label': 'car', 'confidence': 0.2552099, 'topleft': {'x': 1364, 'y': 410}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 653}, 'label': 'car', 'confidence': 0.42378524, 'topleft': {'x': 1668, 'y': 585}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1256, 'y': 417}, 'label': 'car', 'confidence': 0.55535513, 'topleft': {'x': 1213, 'y': 391}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1399, 'y': 434}, 'label': 'car', 'confidence': 0.26930115, 'topleft': {'x': 1364, 'y': 408}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 637}, 'label': 'car', 'confidence': 0.36949337, 'topleft': {'x': 1700, 'y': 579}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1402, 'y': 435}, 'label': 'car', 'confidence': 0.27972907, 'topleft': {'x': 1366, 'y': 408}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1401, 'y': 435}, 'label': 'car', 'confidence': 0.27081048, 'topleft': {'x': 1367, 'y': 409}}
# FPS         24.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1258, 'y': 418}, 'label': 'car', 'confidence': 0.4329677, 'topleft': {'x': 1222, 'y': 394}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1258, 'y': 418}, 'label': 'car', 'confidence': 0.43455115, 'topleft': {'x': 1222, 'y': 395}}
# FPS         22.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1263, 'y': 417}, 'label': 'car', 'confidence': 0.41851592, 'topleft': {'x': 1225, 'y': 393}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1796, 'y': 655}, 'label': 'car', 'confidence': 0.43965718, 'topleft': {'x': 1669, 'y': 583}}
# FPS         23.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 634}, 'label': 'car', 'confidence': 0.33458838, 'topleft': {'x': 1703, 'y': 578}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 654}, 'label': 'car', 'confidence': 0.446053, 'topleft': {'x': 1669, 'y': 584}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 653}, 'label': 'car', 'confidence': 0.45602062, 'topleft': {'x': 1669, 'y': 584}}
# FPS         24.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1265, 'y': 417}, 'label': 'car', 'confidence': 0.35921928, 'topleft': {'x': 1227, 'y': 393}}
# FPS         21.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1264, 'y': 418}, 'label': 'car', 'confidence': 0.4217325, 'topleft': {'x': 1224, 'y': 393}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1267, 'y': 417}, 'label': 'car', 'confidence': 0.34315497, 'topleft': {'x': 1228, 'y': 393}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1269, 'y': 418}, 'label': 'car', 'confidence': 0.2883997, 'topleft': {'x': 1231, 'y': 394}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1795, 'y': 654}, 'label': 'car', 'confidence': 0.46433428, 'topleft': {'x': 1669, 'y': 583}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1268, 'y': 418}, 'label': 'car', 'confidence': 0.27287334, 'topleft': {'x': 1231, 'y': 396}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1792, 'y': 653}, 'label': 'car', 'confidence': 0.41170207, 'topleft': {'x': 1670, 'y': 584}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 653}, 'label': 'car', 'confidence': 0.41245225, 'topleft': {'x': 1669, 'y': 584}}
# FPS         23.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 653}, 'label': 'car', 'confidence': 0.43431985, 'topleft': {'x': 1670, 'y': 585}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1793, 'y': 652}, 'label': 'car', 'confidence': 0.38341773, 'topleft': {'x': 1670, 'y': 584}}
# FPS         23.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 635}, 'label': 'car', 'confidence': 0.4218331, 'topleft': {'x': 1698, 'y': 578}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 634}, 'label': 'car', 'confidence': 0.42628908, 'topleft': {'x': 1697, 'y': 578}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1808, 'y': 710}, 'label': 'car', 'confidence': 0.31598037, 'topleft': {'x': 1669, 'y': 597}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 633}, 'label': 'car', 'confidence': 0.42545855, 'topleft': {'x': 1698, 'y': 578}}
# FPS         22.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 634}, 'label': 'car', 'confidence': 0.4530403, 'topleft': {'x': 1697, 'y': 577}}
# FPS         23.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1776, 'y': 634}, 'label': 'car', 'confidence': 0.43523666, 'topleft': {'x': 1699, 'y': 577}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1774, 'y': 635}, 'label': 'car', 'confidence': 0.36856994, 'topleft': {'x': 1701, 'y': 579}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1775, 'y': 634}, 'label': 'car', 'confidence': 0.41343284, 'topleft': {'x': 1700, 'y': 578}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1228, 'y': 434}, 'label': 'car', 'confidence': 0.5855686, 'topleft': {'x': 1161, 'y': 394}}
# FPS         22.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 636}, 'label': 'car', 'confidence': 0.38993964, 'topleft': {'x': 1698, 'y': 579}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 635}, 'label': 'car', 'confidence': 0.38571003, 'topleft': {'x': 1699, 'y': 579}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 635}, 'label': 'car', 'confidence': 0.3813158, 'topleft': {'x': 1699, 'y': 578}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1233, 'y': 432}, 'label': 'car', 'confidence': 0.4944995, 'topleft': {'x': 1168, 'y': 393}}
# FPS         23.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 634}, 'label': 'car', 'confidence': 0.40231007, 'topleft': {'x': 1699, 'y': 579}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 634}, 'label': 'car', 'confidence': 0.39284334, 'topleft': {'x': 1700, 'y': 579}}
# FPS         21.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 634}, 'label': 'car', 'confidence': 0.39412138, 'topleft': {'x': 1699, 'y': 578}}
# FPS         21.0
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 634}, 'label': 'car', 'confidence': 0.37337977, 'topleft': {'x': 1701, 'y': 579}}
# FPS         22.2
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1775, 'y': 634}, 'label': 'car', 'confidence': 0.35647506, 'topleft': {'x': 1701, 'y': 579}}
# FPS         21.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 318, 'y': 755}, 'label': 'car', 'confidence': 0.3923321, 'topleft': {'x': 160, 'y': 668}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1797, 'y': 655}, 'label': 'car', 'confidence': 0.38791746, 'topleft': {'x': 1670, 'y': 583}}
# FPS         23.8
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1403, 'y': 436}, 'label': 'car', 'confidence': 0.27028218, 'topleft': {'x': 1368, 'y': 411}}
# FPS         22.7
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1403, 'y': 436}, 'label': 'car', 'confidence': 0.25068143, 'topleft': {'x': 1367, 'y': 411}}
# FPS         22.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1256, 'y': 429}, 'label': 'car', 'confidence': 0.42634082, 'topleft': {'x': 1206, 'y': 404}}
# FPS         22.9
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1257, 'y': 427}, 'label': 'car', 'confidence': 0.4220835, 'topleft': {'x': 1210, 'y': 403}}
# FPS         23.5
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1401, 'y': 437}, 'label': 'car', 'confidence': 0.25172195, 'topleft': {'x': 1366, 'y': 413}}
# FPS         22.4
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1777, 'y': 636}, 'label': 'car', 'confidence': 0.39442885, 'topleft': {'x': 1697, 'y': 579}}
# FPS         22.1
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 636}, 'label': 'car', 'confidence': 0.4282159, 'topleft': {'x': 1696, 'y': 579}}
# FPS         22.3
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1778, 'y': 637}, 'label': 'car', 'confidence': 0.44062597, 'topleft': {'x': 1696, 'y': 579}}
# FPS         23.6
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# Results:        {'bottomright': {'x': 1264, 'y': 424}, 'label': 'car', 'confidence': 0.2974938, 'topleft': {'x': 1225, 'y': 399}}
# FPS         24.2
# ++++++++ Video End ++++++++

# %% [markdown]
# ## Pre-process (b)

# %%
count = 0
while(True):
    stime = time.time()
    start = timer()
    ret, frame = capture.read()

    if ret == False:
        break;
    else:
        count = count + 1

    frame = np.stack((frame[:,:,0],frame[:,:,0],frame[:,:,0]),axis=2)
    #results = tfnet.return_predict(frame)
    #
    preprocessed = tfnet.framework.preprocess(frame)
    feed_dict = {tfnet.inp: [preprocessed]}
    net_out = tfnet.sess.run(tfnet.out,feed_dict)[0]

    processed = tfnet.framework.postprocess(net_out, frame, False)
    #
    out.write(processed)
    cv2.imshow('frame', processed)
    #
    print("Shape of Frame: {}".format(frame.shape))
    print("Type of Frame:  {}".format(type(frame)))
    #print("Results:        {}".format(processed))
    print('FPS {:.1f}'.format(1 / (time.time() - stime)))  # Frame per seconds
    print('Elapsed time = ' + str(timer() - start) + ' s')
    #
    if (cv2.waitKey(1) & 0xFF == ord('q')) or (ret == False):
        break

print('++++++++ Video End ++++++++')

capture.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 12.9
# Elapsed time = 0.07781195640563965 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.8
# Elapsed time = 0.053253173828125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.051301002502441406 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.7
# Elapsed time = 0.05355119705200195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05041790008544922 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.1
# Elapsed time = 0.05229473114013672 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.4
# Elapsed time = 0.05426359176635742 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05155801773071289 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05090737342834473 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.7
# Elapsed time = 0.050890207290649414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.049807071685791016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04877328872680664 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.8
# Elapsed time = 0.06334972381591797 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.9
# Elapsed time = 0.0528569221496582 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.05121183395385742 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04822230339050293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.7
# Elapsed time = 0.05356645584106445 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048184871673583984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04677891731262207 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04652142524719238 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04728436470031738 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.05251193046569824 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05022382736206055 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.049662113189697266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.4
# Elapsed time = 0.05762195587158203 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.1
# Elapsed time = 0.05513143539428711 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.3
# Elapsed time = 0.054645538330078125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04830169677734375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04920148849487305 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048708200454711914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05100893974304199 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04832601547241211 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04848194122314453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.5
# Elapsed time = 0.0570526123046875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.0
# Elapsed time = 0.055690765380859375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.4
# Elapsed time = 0.05755901336669922 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.0
# Elapsed time = 0.05890250205993652 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046468257904052734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05014753341674805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04808855056762695 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04743337631225586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04805469512939453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046450138092041016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04984927177429199 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04703688621520996 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04743766784667969 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.0495305061340332 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04979395866394043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04955649375915527 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.9
# Elapsed time = 0.05289268493652344 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.9
# Elapsed time = 0.056035518646240234 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.7
# Elapsed time = 0.05651688575744629 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.6
# Elapsed time = 0.05673956871032715 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.1
# Elapsed time = 0.05531477928161621 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05059194564819336 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04985785484313965 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.0
# Elapsed time = 0.058962106704711914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.2
# Elapsed time = 0.057987213134765625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.4
# Elapsed time = 0.05438685417175293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.3
# Elapsed time = 0.05471444129943848 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04981064796447754 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046610116958618164 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 16.9
# Elapsed time = 0.05920076370239258 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.1
# Elapsed time = 0.058472394943237305 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.4
# Elapsed time = 0.05755877494812012 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.8
# Elapsed time = 0.05321073532104492 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.2
# Elapsed time = 0.052221059799194336 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04607415199279785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.049498796463012695 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04706406593322754 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.04997897148132324 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04779648780822754 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.05128979682922363 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05165576934814453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048166751861572266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04750323295593262 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0481564998626709 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047563791275024414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05007648468017578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048583030700683594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.0473477840423584 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04699397087097168 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046566009521484375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046006202697753906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04892158508300781 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04691743850708008 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05002999305725098 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.6
# Elapsed time = 0.053908348083496094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.0493927001953125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04665231704711914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0480189323425293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.8
# Elapsed time = 0.05616164207458496 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.0465395450592041 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04870343208312988 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05054831504821777 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.05251121520996094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.1
# Elapsed time = 0.05234193801879883 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04639005661010742 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046091318130493164 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.0463559627532959 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046562910079956055 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04819297790527344 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05093121528625488 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04841756820678711 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.04989361763000488 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.049635887145996094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04707145690917969 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.0488584041595459 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.048963069915771484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04745197296142578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05019855499267578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.049971818923950195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.049034833908081055 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04917311668395996 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04628276824951172 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04675412178039551 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05006718635559082 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04840397834777832 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05036139488220215 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04752016067504883 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04860401153564453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04713869094848633 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04677581787109375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04734230041503906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046890974044799805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.050093889236450195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.0513911247253418 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.7
# Elapsed time = 0.05071759223937988 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0481417179107666 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04797029495239258 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04628634452819824 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04683184623718262 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04944300651550293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047905683517456055 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.3
# Elapsed time = 0.05193734169006348 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05054044723510742 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04978370666503906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04677128791809082 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04690957069396973 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046895503997802734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04610943794250488 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.6
# Elapsed time = 0.053847312927246094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.049999237060546875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04766273498535156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04985785484313965 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04679083824157715 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046408891677856445 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04656553268432617 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047487735748291016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048477888107299805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.05269908905029297 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04789328575134277 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047609567642211914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04752683639526367 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04706144332885742 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046074867248535156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04885458946228027 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048547983169555664 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.051380157470703125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.0487673282623291 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04921150207519531 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04773235321044922 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04684758186340332 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04645133018493652 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04621767997741699 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05154109001159668 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05033755302429199 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04771566390991211 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04918527603149414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04658341407775879 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04814004898071289 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046984195709228516 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046293020248413086 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.7
# Elapsed time = 0.0506434440612793 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04958796501159668 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04756903648376465 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04737710952758789 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047440290451049805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04716181755065918 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04719424247741699 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04858541488647461 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04723405838012695 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04934358596801758 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047103166580200195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046341657638549805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047396183013916016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046946048736572266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04691338539123535 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04862642288208008 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04852557182312012 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04898571968078613 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0479884147644043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.0495610237121582 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04668855667114258 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04622793197631836 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04739689826965332 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05048179626464844 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04810142517089844 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.049566030502319336 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04701042175292969 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04671978950500488 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.049028873443603516 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046898841857910156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.8
# Elapsed time = 0.0459592342376709 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.048989295959472656 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04825901985168457 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04895281791687012 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04726719856262207 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046454668045043945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04918479919433594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04857230186462402 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04696249961853027 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04603886604309082 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04779982566833496 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04949188232421875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.0477147102355957 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04857659339904785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04878377914428711 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.8
# Elapsed time = 0.04598593711853027 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05046653747558594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046985626220703125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04676222801208496 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.049276113510131836 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048133134841918945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04633188247680664 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046980857849121094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046102046966552734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046866655349731445 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.7
# Elapsed time = 0.05357933044433594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04790472984313965 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.049840688705444336 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04799628257751465 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.7
# Elapsed time = 0.05076479911804199 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04674077033996582 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04677748680114746 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046919822692871094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04792356491088867 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04625725746154785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04986286163330078 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04835176467895508 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.05138421058654785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04609799385070801 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04606318473815918 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04892420768737793 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04789018630981445 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04772019386291504 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.050002336502075195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04767894744873047 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04869532585144043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04680061340332031 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046102046966552734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04652261734008789 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.048719167709350586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04810762405395508 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04930567741394043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04787039756774902 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046977996826171875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04658865928649902 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04717898368835449 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047122955322265625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.046750545501708984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.0488126277923584 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.049407958984375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.0503993034362793 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048596858978271484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04740786552429199 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04734492301940918 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04631972312927246 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04774641990661621 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04903697967529297 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.050511837005615234 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04739570617675781 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046614885330200195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04732465744018555 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.0485835075378418 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04612302780151367 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04835772514343262 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.048769235610961914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04968380928039551 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04848837852478027 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047661781311035156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047887325286865234 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05109453201293945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.046833038330078125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04732704162597656 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047803401947021484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.050989627838134766 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.0487828254699707 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05005335807800293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04772615432739258 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.049214839935302734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04904365539550781 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05019235610961914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048093318939208984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05097079277038574 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.04993605613708496 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04832601547241211 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05004119873046875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04815530776977539 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.0496213436126709 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 18.9
# Elapsed time = 0.05284285545349121 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04712986946105957 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05158257484436035 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.050046682357788086 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047785043716430664 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.049279212951660156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.047031402587890625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047078609466552734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048194169998168945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04794049263000488 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05003809928894043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04899001121520996 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.052579641342163086 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04813981056213379 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04741716384887695 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04662179946899414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04706716537475586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04846048355102539 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05038809776306152 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048169851303100586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04808616638183594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047898292541503906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04620051383972168 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04899096488952637 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04922056198120117 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04704141616821289 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04947781562805176 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04762077331542969 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0481259822845459 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04878950119018555 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047940731048583984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04613828659057617 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046442508697509766 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04862213134765625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.049726009368896484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04718470573425293 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04924488067626953 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04777073860168457 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04625415802001953 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04609537124633789 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04643869400024414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04911637306213379 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04949164390563965 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047667741775512695 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04636383056640625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.048891544342041016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046462297439575195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04721856117248535 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04834342002868652 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04825901985168457 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05032229423522949 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048478126525878906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05055403709411621 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047451019287109375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04757404327392578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.04607343673706055 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046289920806884766 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.050154685974121094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.049423933029174805 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04776334762573242 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04813098907470703 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.050304412841796875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04674029350280762 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.0471799373626709 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047255516052246094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.8
# Elapsed time = 0.04595470428466797 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04925417900085449 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047734737396240234 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04679298400878906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047902822494506836 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04624176025390625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046495676040649414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.048232316970825195 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04800701141357422 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04983210563659668 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.8
# Elapsed time = 0.05051159858703613 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04749488830566406 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04658985137939453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047548770904541016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04890751838684082 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04697585105895996 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04696345329284668 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04958200454711914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04844808578491211 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.049051523208618164 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04725503921508789 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.046773433685302734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047396183013916016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04760098457336426 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.2
# Elapsed time = 0.04960441589355469 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05115509033203125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04779863357543945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04781031608581543 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04706525802612305 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04694795608520508 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.0464174747467041 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04886174201965332 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.048635005950927734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04881620407104492 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.049294233322143555 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04729580879211426 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04870033264160156 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046375274658203125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046572208404541016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04645872116088867 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04927992820739746 s
# ...
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.04996061325073242 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04754185676574707 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.7
# Elapsed time = 0.0508730411529541 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.0479888916015625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04776167869567871 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04819822311401367 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04640603065490723 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.047025203704833984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04665350914001465 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04671216011047363 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05145096778869629 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047799110412597656 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.048919677734375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04728341102600098 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04789543151855469 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046346426010131836 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.05001544952392578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05029177665710449 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.9
# Elapsed time = 0.05023503303527832 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05098390579223633 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04778099060058594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04925823211669922 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046267032623291016 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047106027603149414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.05257129669189453 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046946048736572266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05145072937011719 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04764366149902344 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04855060577392578 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04665231704711914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04762554168701172 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.04848790168762207 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.8
# Elapsed time = 0.04591488838195801 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046918392181396484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.9
# Elapsed time = 0.05592799186706543 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047551631927490234 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.050089359283447266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04745650291442871 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047284841537475586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04656648635864258 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04688763618469238 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04661679267883301 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 17.0
# Elapsed time = 0.05870842933654785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047913551330566406 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047241926193237305 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.047827959060668945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04648852348327637 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04871869087219238 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04907584190368652 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.0475153923034668 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.04991626739501953 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04878878593444824 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.0473170280456543 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04718780517578125 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04745292663574219 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04645037651062012 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04652261734008789 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04669618606567383 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.6
# Elapsed time = 0.05115151405334473 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04775547981262207 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04905986785888672 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04744887351989746 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04744911193847656 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.04643392562866211 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.046392202377319336 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04745054244995117 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.051480770111083984 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047331809997558594 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047675371170043945 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.0514063835144043 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.8
# Elapsed time = 0.04581928253173828 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.0464327335357666 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04978775978088379 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047402143478393555 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.0
# Elapsed time = 0.05264925956726074 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04797720909118652 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04677081108093262 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04805731773376465 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04720425605773926 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046517133712768555 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047070980072021484 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04706692695617676 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.2
# Elapsed time = 0.051987648010253906 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.048044443130493164 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.6
# Elapsed time = 0.0485386848449707 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04712653160095215 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.047669410705566406 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.046956539154052734 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.0464777946472168 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.7
# Elapsed time = 0.046140432357788086 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.3
# Elapsed time = 0.05192232131958008 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04816603660583496 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04867434501647949 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.0513913631439209 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04700875282287598 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.0462803840637207 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04890632629394531 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04836273193359375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.1
# Elapsed time = 0.05248522758483887 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.0476224422454834 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04735589027404785 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.047316551208496094 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.048746585845947266 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04833626747131348 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.6
# Elapsed time = 0.04627108573913574 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04710650444030762 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.5
# Elapsed time = 0.05129814147949219 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04791855812072754 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04899120330810547 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.0
# Elapsed time = 0.04765963554382324 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04712343215942383 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.4
# Elapsed time = 0.05167031288146973 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.04674410820007324 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04888010025024414 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.3
# Elapsed time = 0.051784515380859375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.049837350845336914 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.04716038703918457 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.1
# Elapsed time = 0.04977893829345703 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.04939103126525879 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.3
# Elapsed time = 0.04697418212890625 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04822254180908203 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.4
# Elapsed time = 0.04896831512451172 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 19.3
# Elapsed time = 0.05177474021911621 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.7
# Elapsed time = 0.04822397232055664 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047206878662109375 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.2
# Elapsed time = 0.047150373458862305 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04731392860412598 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.5
# Elapsed time = 0.04883599281311035 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.8
# Elapsed time = 0.04818987846374512 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.5
# Elapsed time = 0.046582937240600586 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.0
# Elapsed time = 0.0500032901763916 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.1
# Elapsed time = 0.04748392105102539 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.9
# Elapsed time = 0.04776358604431152 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 21.4
# Elapsed time = 0.046672821044921875 s
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 20.3
# Elapsed time = 0.049248695373535156 s
# ++++++++ Video End ++++++++

# %% [markdown]
# ## Pre-process (c)

# %%
count = 0
while(True):
    stime = time.time()
    start = timer()
    ret, frame = capture.read()

    if ret == False:
        break;
    else:
        count = count + 1

    #frame = np.stack((frame[:,:,0],frame[:,:,0],frame[:,:,0]),axis=2)
    #results = tfnet.return_predict(frame)
    #
    h, w, _ = frame.shape
    
    preprocessed = tfnet.framework.preprocess(frame)
    feed_dict = {tfnet.inp: [preprocessed]}
    net_out = tfnet.sess.run(tfnet.out, feed_dict)[0]

    processed = tfnet.framework.postprocess(net_out, frame, False)
    
    ###############
    # Boxes Info  #
    ###############
    outc2 = tfnet.sess.run(tfnet.out, feed_dict)[0]
    boxes = tfnet.framework.findboxes(outc2)

    threshold = tfnet.FLAGS.threshold

    boxesInfo = list()
    #
    for box in boxes:
        tmpBox = tfnet.framework.process_box(box, h, w, threshold)
        if tmpBox is None:
            continue
        boxesInfo.append({
            "label": tmpBox[4],
            "confidence": tmpBox[6],
            "topleft": {
                "x": tmpBox[0],
                "y": tmpBox[2]},
            "bottomright": {
                "x": tmpBox[1],
                "y": tmpBox[3]}
        })
    #
    print(boxesInfo)
    #
    out.write(processed)
    cv2.imshow('frame', processed)
    #
    print("Shape of Frame: {}".format(frame.shape))
    print("Type of Frame:  {}".format(type(frame)))
    #print("Results:        {}".format(processed))
    print('FPS {:.1f}'.format(1 / (time.time() - stime)))  # Frame per seconds
    print('Elapsed time = ' + str(timer() - start) + ' s')    
    if (cv2.waitKey(1) & 0xFF == ord('q')) or (ret == False):
        break

print('++++++++ Video End ++++++++')

capture.release()
out.release()
cv2.destroyAllWindows()
# Out:
# [{'bottomright': {'x': 1403, 'y': 437}, 'label': 'car', 'confidence': 0.2592506, 'topleft': {'x': 1366, 'y': 411}}, {'bottomright': {'x': 1790, 'y': 640}, 'label': 'car', 'confidence': 0.60196817, 'topleft': {'x': 1688, 'y': 580}}, {'bottomright': {'x': 1813, 'y': 700}, 'label': 'car', 'confidence': 0.28795245, 'topleft': {'x': 1690, 'y': 598}}, {'bottomright': {'x': 316, 'y': 756}, 'label': 'car', 'confidence': 0.35832927, 'topleft': {'x': 151, 'y': 671}}, {'bottomright': {'x': 1858, 'y': 740}, 'label': 'car', 'confidence': 0.5496255, 'topleft': {'x': 1732, 'y': 652}}, {'bottomright': {'x': 353, 'y': 810}, 'label': 'car', 'confidence': 0.47229612, 'topleft': {'x': 183, 'y': 723}}, {'bottomright': {'x': 528, 'y': 811}, 'label': 'car', 'confidence': 0.28289562, 'topleft': {'x': 392, 'y': 727}}, {'bottomright': {'x': 1781, 'y': 858}, 'label': 'car', 'confidence': 0.73106915, 'topleft': {'x': 1598, 'y': 657}}, {'bottomright': {'x': 428, 'y': 865}, 'label': 'car', 'confidence': 0.5539688, 'topleft': {'x': 242, 'y': 774}}, {'bottomright': {'x': 81, 'y': 954}, 'label': 'car', 'confidence': 0.37072465, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 534, 'y': 938}, 'label': 'car', 'confidence': 0.316663, 'topleft': {'x': 400, 'y': 844}}, {'bottomright': {'x': 605, 'y': 934}, 'label': 'car', 'confidence': 0.3302904, 'topleft': {'x': 486, 'y': 845}}, {'bottomright': {'x': 551, 'y': 989}, 'label': 'car', 'confidence': 0.42664623, 'topleft': {'x': 402, 'y': 877}}, {'bottomright': {'x': 1888, 'y': 479}, 'label': 'traffic light', 'confidence': 0.28846404, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 9.7
# Elapsed time = 0.10324716567993164 s
# [{'bottomright': {'x': 879, 'y': 1077}, 'label': 'person', 'confidence': 0.28568313, 'topleft': {'x': 715, 'y': 929}}, {'bottomright': {'x': 1790, 'y': 640}, 'label': 'car', 'confidence': 0.5891911, 'topleft': {'x': 1690, 'y': 580}}, {'bottomright': {'x': 1814, 'y': 704}, 'label': 'car', 'confidence': 0.41341087, 'topleft': {'x': 1685, 'y': 602}}, {'bottomright': {'x': 315, 'y': 756}, 'label': 'car', 'confidence': 0.36227238, 'topleft': {'x': 152, 'y': 671}}, {'bottomright': {'x': 1847, 'y': 736}, 'label': 'car', 'confidence': 0.5003806, 'topleft': {'x': 1723, 'y': 652}}, {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.4620388, 'topleft': {'x': 184, 'y': 723}}, {'bottomright': {'x': 530, 'y': 812}, 'label': 'car', 'confidence': 0.26798722, 'topleft': {'x': 393, 'y': 728}}, {'bottomright': {'x': 1788, 'y': 860}, 'label': 'car', 'confidence': 0.74932206, 'topleft': {'x': 1598, 'y': 658}}, {'bottomright': {'x': 427, 'y': 865}, 'label': 'car', 'confidence': 0.5478586, 'topleft': {'x': 243, 'y': 774}}, {'bottomright': {'x': 80, 'y': 954}, 'label': 'car', 'confidence': 0.3784879, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 533, 'y': 938}, 'label': 'car', 'confidence': 0.33519924, 'topleft': {'x': 400, 'y': 844}}, {'bottomright': {'x': 604, 'y': 934}, 'label': 'car', 'confidence': 0.32077056, 'topleft': {'x': 485, 'y': 845}}, {'bottomright': {'x': 550, 'y': 989}, 'label': 'car', 'confidence': 0.4282669, 'topleft': {'x': 404, 'y': 878}}, {'bottomright': {'x': 1888, 'y': 479}, 'label': 'traffic light', 'confidence': 0.2889411, 'topleft': {'x': 1858, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 12.8
# Elapsed time = 0.07807087898254395 s
# [{'bottomright': {'x': 879, 'y': 1079}, 'label': 'person', 'confidence': 0.34135118, 'topleft': {'x': 715, 'y': 928}}, {'bottomright': {'x': 1400, 'y': 437}, 'label': 'car', 'confidence': 0.25474656, 'topleft': {'x': 1365, 'y': 412}}, {'bottomright': {'x': 1787, 'y': 640}, 'label': 'car', 'confidence': 0.59623826, 'topleft': {'x': 1689, 'y': 580}}, {'bottomright': {'x': 1811, 'y': 705}, 'label': 'car', 'confidence': 0.39635417, 'topleft': {'x': 1685, 'y': 606}}, {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.35934627, 'topleft': {'x': 154, 'y': 671}}, {'bottomright': {'x': 1850, 'y': 734}, 'label': 'car', 'confidence': 0.5420736, 'topleft': {'x': 1712, 'y': 652}}, {'bottomright': {'x': 352, 'y': 809}, 'label': 'car', 'confidence': 0.4585043, 'topleft': {'x': 185, 'y': 723}}, {'bottomright': {'x': 1787, 'y': 864}, 'label': 'car', 'confidence': 0.73599035, 'topleft': {'x': 1595, 'y': 659}}, {'bottomright': {'x': 426, 'y': 864}, 'label': 'car', 'confidence': 0.534851, 'topleft': {'x': 243, 'y': 775}}, {'bottomright': {'x': 79, 'y': 954}, 'label': 'car', 'confidence': 0.36787903, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 535, 'y': 937}, 'label': 'car', 'confidence': 0.3350851, 'topleft': {'x': 399, 'y': 844}}, {'bottomright': {'x': 602, 'y': 931}, 'label': 'car', 'confidence': 0.3118989, 'topleft': {'x': 484, 'y': 846}}, {'bottomright': {'x': 552, 'y': 988}, 'label': 'car', 'confidence': 0.43651167, 'topleft': {'x': 404, 'y': 878}}, {'bottomright': {'x': 1887, 'y': 479}, 'label': 'traffic light', 'confidence': 0.30480883, 'topleft': {'x': 1856, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.0
# Elapsed time = 0.07136154174804688 s
# [{'bottomright': {'x': 878, 'y': 1078}, 'label': 'person', 'confidence': 0.314427, 'topleft': {'x': 717, 'y': 929}}, {'bottomright': {'x': 1402, 'y': 438}, 'label': 'car', 'confidence': 0.25544336, 'topleft': {'x': 1366, 'y': 413}}, {'bottomright': {'x': 1788, 'y': 636}, 'label': 'car', 'confidence': 0.55171496, 'topleft': {'x': 1693, 'y': 579}}, {'bottomright': {'x': 1816, 'y': 705}, 'label': 'car', 'confidence': 0.4331649, 'topleft': {'x': 1685, 'y': 608}}, {'bottomright': {'x': 317, 'y': 756}, 'label': 'car', 'confidence': 0.3566666, 'topleft': {'x': 155, 'y': 671}}, {'bottomright': {'x': 1852, 'y': 738}, 'label': 'car', 'confidence': 0.54147685, 'topleft': {'x': 1708, 'y': 652}}, {'bottomright': {'x': 354, 'y': 808}, 'label': 'car', 'confidence': 0.46825784, 'topleft': {'x': 186, 'y': 723}}, {'bottomright': {'x': 1798, 'y': 866}, 'label': 'car', 'confidence': 0.71026075, 'topleft': {'x': 1601, 'y': 663}}, {'bottomright': {'x': 427, 'y': 864}, 'label': 'car', 'confidence': 0.5260326, 'topleft': {'x': 243, 'y': 776}}, {'bottomright': {'x': 1781, 'y': 863}, 'label': 'car', 'confidence': 0.48339733, 'topleft': {'x': 1662, 'y': 760}}, {'bottomright': {'x': 80, 'y': 953}, 'label': 'car', 'confidence': 0.37201473, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 535, 'y': 937}, 'label': 'car', 'confidence': 0.33146426, 'topleft': {'x': 399, 'y': 844}}, {'bottomright': {'x': 603, 'y': 933}, 'label': 'car', 'confidence': 0.3045121, 'topleft': {'x': 485, 'y': 846}}, {'bottomright': {'x': 550, 'y': 989}, 'label': 'car', 'confidence': 0.42276227, 'topleft': {'x': 403, 'y': 878}}, {'bottomright': {'x': 1888, 'y': 479}, 'label': 'traffic light', 'confidence': 0.28839308, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 12.0
# Elapsed time = 0.08325457572937012 s
# [{'bottomright': {'x': 880, 'y': 1078}, 'label': 'person', 'confidence': 0.29300758, 'topleft': {'x': 715, 'y': 928}}, {'bottomright': {'x': 1789, 'y': 633}, 'label': 'car', 'confidence': 0.5529689, 'topleft': {'x': 1690, 'y': 578}}, {'bottomright': {'x': 1812, 'y': 706}, 'label': 'car', 'confidence': 0.48429546, 'topleft': {'x': 1685, 'y': 607}}, {'bottomright': {'x': 317, 'y': 755}, 'label': 'car', 'confidence': 0.36893168, 'topleft': {'x': 152, 'y': 672}}, {'bottomright': {'x': 1845, 'y': 738}, 'label': 'car', 'confidence': 0.43599457, 'topleft': {'x': 1710, 'y': 651}}, {'bottomright': {'x': 353, 'y': 808}, 'label': 'car', 'confidence': 0.4649835, 'topleft': {'x': 183, 'y': 722}}, {'bottomright': {'x': 1804, 'y': 866}, 'label': 'car', 'confidence': 0.68513757, 'topleft': {'x': 1596, 'y': 660}}, {'bottomright': {'x': 427, 'y': 864}, 'label': 'car', 'confidence': 0.52914363, 'topleft': {'x': 241, 'y': 775}}, {'bottomright': {'x': 1786, 'y': 865}, 'label': 'car', 'confidence': 0.35336304, 'topleft': {'x': 1664, 'y': 764}}, {'bottomright': {'x': 80, 'y': 953}, 'label': 'car', 'confidence': 0.3762975, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 536, 'y': 937}, 'label': 'car', 'confidence': 0.3377472, 'topleft': {'x': 399, 'y': 842}}, {'bottomright': {'x': 604, 'y': 934}, 'label': 'car', 'confidence': 0.31046414, 'topleft': {'x': 482, 'y': 846}}, {'bottomright': {'x': 550, 'y': 988}, 'label': 'car', 'confidence': 0.41730198, 'topleft': {'x': 404, 'y': 877}}, {'bottomright': {'x': 1888, 'y': 479}, 'label': 'traffic light', 'confidence': 0.29228875, 'topleft': {'x': 1857, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.9
# Elapsed time = 0.06694698333740234 s
# [{'bottomright': {'x': 879, 'y': 1078}, 'label': 'person', 'confidence': 0.31311688, 'topleft': {'x': 715, 'y': 929}}, {'bottomright': {'x': 1789, 'y': 634}, 'label': 'car', 'confidence': 0.56037456, 'topleft': {'x': 1691, 'y': 578}}, {'bottomright': {'x': 1816, 'y': 705}, 'label': 'car', 'confidence': 0.4441387, 'topleft': {'x': 1682, 'y': 609}}, {'bottomright': {'x': 317, 'y': 755}, 'label': 'car', 'confidence': 0.36044112, 'topleft': {'x': 152, 'y': 672}}, {'bottomright': {'x': 1841, 'y': 736}, 'label': 'car', 'confidence': 0.47197005, 'topleft': {'x': 1705, 'y': 650}}, {'bottomright': {'x': 353, 'y': 808}, 'label': 'car', 'confidence': 0.4464657, 'topleft': {'x': 182, 'y': 722}}, {'bottomright': {'x': 1802, 'y': 871}, 'label': 'car', 'confidence': 0.6547731, 'topleft': {'x': 1598, 'y': 660}}, {'bottomright': {'x': 429, 'y': 864}, 'label': 'car', 'confidence': 0.51978165, 'topleft': {'x': 241, 'y': 776}}, {'bottomright': {'x': 1787, 'y': 873}, 'label': 'car', 'confidence': 0.4611312, 'topleft': {'x': 1666, 'y': 763}}, {'bottomright': {'x': 80, 'y': 953}, 'label': 'car', 'confidence': 0.36719447, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 536, 'y': 937}, 'label': 'car', 'confidence': 0.31905425, 'topleft': {'x': 399, 'y': 844}}, {'bottomright': {'x': 604, 'y': 933}, 'label': 'car', 'confidence': 0.289169, 'topleft': {'x': 483, 'y': 845}}, {'bottomright': {'x': 549, 'y': 988}, 'label': 'car', 'confidence': 0.410333, 'topleft': {'x': 402, 'y': 878}}, {'bottomright': {'x': 1888, 'y': 479}, 'label': 'traffic light', 'confidence': 0.30682123, 'topleft': {'x': 1857, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.2
# Elapsed time = 0.07593512535095215 s
# [{'bottomright': {'x': 882, 'y': 1079}, 'label': 'person', 'confidence': 0.36797395, 'topleft': {'x': 713, 'y': 926}}, {'bottomright': {'x': 1787, 'y': 633}, 'label': 'car', 'confidence': 0.5085704, 'topleft': {'x': 1695, 'y': 577}}, {'bottomright': {'x': 1813, 'y': 703}, 'label': 'car', 'confidence': 0.4621328, 'topleft': {'x': 1681, 'y': 609}}, {'bottomright': {'x': 313, 'y': 756}, 'label': 'car', 'confidence': 0.37611645, 'topleft': {'x': 151, 'y': 671}}, {'bottomright': {'x': 1851, 'y': 733}, 'label': 'car', 'confidence': 0.49220586, 'topleft': {'x': 1768, 'y': 652}}, {'bottomright': {'x': 352, 'y': 810}, 'label': 'car', 'confidence': 0.4508139, 'topleft': {'x': 183, 'y': 723}}, {'bottomright': {'x': 1819, 'y': 887}, 'label': 'car', 'confidence': 0.6794351, 'topleft': {'x': 1599, 'y': 644}}, {'bottomright': {'x': 430, 'y': 864}, 'label': 'car', 'confidence': 0.5311828, 'topleft': {'x': 241, 'y': 775}}, {'bottomright': {'x': 78, 'y': 954}, 'label': 'car', 'confidence': 0.30952787, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 541, 'y': 936}, 'label': 'car', 'confidence': 0.31266886, 'topleft': {'x': 401, 'y': 845}}, {'bottomright': {'x': 597, 'y': 933}, 'label': 'car', 'confidence': 0.28619, 'topleft': {'x': 477, 'y': 845}}, {'bottomright': {'x': 551, 'y': 988}, 'label': 'car', 'confidence': 0.40238726, 'topleft': {'x': 398, 'y': 876}}, {'bottomright': {'x': 1886, 'y': 477}, 'label': 'traffic light', 'confidence': 0.34230453, 'topleft': {'x': 1856, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.1
# Elapsed time = 0.07110190391540527 s
# [{'bottomright': {'x': 882, 'y': 1079}, 'label': 'person', 'confidence': 0.42883715, 'topleft': {'x': 716, 'y': 925}}, {'bottomright': {'x': 1787, 'y': 632}, 'label': 'car', 'confidence': 0.51540667, 'topleft': {'x': 1693, 'y': 577}}, {'bottomright': {'x': 1817, 'y': 702}, 'label': 'car', 'confidence': 0.4655685, 'topleft': {'x': 1676, 'y': 610}}, {'bottomright': {'x': 314, 'y': 755}, 'label': 'car', 'confidence': 0.38647667, 'topleft': {'x': 152, 'y': 670}}, {'bottomright': {'x': 1843, 'y': 732}, 'label': 'car', 'confidence': 0.48000702, 'topleft': {'x': 1712, 'y': 647}}, {'bottomright': {'x': 403, 'y': 815}, 'label': 'car', 'confidence': 0.46305156, 'topleft': {'x': 246, 'y': 736}}, {'bottomright': {'x': 1820, 'y': 888}, 'label': 'car', 'confidence': 0.7388112, 'topleft': {'x': 1602, 'y': 645}}, {'bottomright': {'x': 431, 'y': 864}, 'label': 'car', 'confidence': 0.5346432, 'topleft': {'x': 239, 'y': 775}}, {'bottomright': {'x': 78, 'y': 955}, 'label': 'car', 'confidence': 0.30346018, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 537, 'y': 935}, 'label': 'car', 'confidence': 0.31971422, 'topleft': {'x': 400, 'y': 846}}, {'bottomright': {'x': 597, 'y': 932}, 'label': 'car', 'confidence': 0.29463744, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 550, 'y': 987}, 'label': 'car', 'confidence': 0.41483018, 'topleft': {'x': 399, 'y': 876}}, {'bottomright': {'x': 180, 'y': 674}, 'label': 'motorbike', 'confidence': 0.25477234, 'topleft': {'x': 103, 'y': 621}}, {'bottomright': {'x': 1886, 'y': 477}, 'label': 'traffic light', 'confidence': 0.32446882, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.9
# Elapsed time = 0.06726431846618652 s
# [{'bottomright': {'x': 882, 'y': 1078}, 'label': 'person', 'confidence': 0.3855756, 'topleft': {'x': 716, 'y': 926}}, {'bottomright': {'x': 1786, 'y': 631}, 'label': 'car', 'confidence': 0.49025607, 'topleft': {'x': 1695, 'y': 578}}, {'bottomright': {'x': 1820, 'y': 705}, 'label': 'car', 'confidence': 0.49870557, 'topleft': {'x': 1675, 'y': 612}}, {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.36019886, 'topleft': {'x': 154, 'y': 669}}, {'bottomright': {'x': 1838, 'y': 736}, 'label': 'car', 'confidence': 0.46757942, 'topleft': {'x': 1703, 'y': 644}}, {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.4575254, 'topleft': {'x': 186, 'y': 724}}, {'bottomright': {'x': 1821, 'y': 886}, 'label': 'car', 'confidence': 0.7349353, 'topleft': {'x': 1623, 'y': 651}}, {'bottomright': {'x': 431, 'y': 863}, 'label': 'car', 'confidence': 0.53530276, 'topleft': {'x': 239, 'y': 776}}, {'bottomright': {'x': 80, 'y': 955}, 'label': 'car', 'confidence': 0.31181052, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 540, 'y': 934}, 'label': 'car', 'confidence': 0.31795776, 'topleft': {'x': 401, 'y': 846}}, {'bottomright': {'x': 593, 'y': 932}, 'label': 'car', 'confidence': 0.3078257, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 549, 'y': 987}, 'label': 'car', 'confidence': 0.41106525, 'topleft': {'x': 399, 'y': 877}}, {'bottomright': {'x': 181, 'y': 674}, 'label': 'motorbike', 'confidence': 0.25401756, 'topleft': {'x': 103, 'y': 620}}, {'bottomright': {'x': 1887, 'y': 478}, 'label': 'traffic light', 'confidence': 0.3280292, 'topleft': {'x': 1857, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.8
# Elapsed time = 0.06780767440795898 s
# [{'bottomright': {'x': 881, 'y': 1078}, 'label': 'person', 'confidence': 0.40437853, 'topleft': {'x': 717, 'y': 927}}, {'bottomright': {'x': 1787, 'y': 631}, 'label': 'car', 'confidence': 0.53283787, 'topleft': {'x': 1691, 'y': 579}}, {'bottomright': {'x': 1826, 'y': 708}, 'label': 'car', 'confidence': 0.54337174, 'topleft': {'x': 1668, 'y': 612}}, {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.36830166, 'topleft': {'x': 155, 'y': 669}}, {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.46321473, 'topleft': {'x': 185, 'y': 724}}, {'bottomright': {'x': 529, 'y': 810}, 'label': 'car', 'confidence': 0.25392875, 'topleft': {'x': 389, 'y': 727}}, {'bottomright': {'x': 1825, 'y': 891}, 'label': 'car', 'confidence': 0.80420667, 'topleft': {'x': 1622, 'y': 658}}, {'bottomright': {'x': 428, 'y': 863}, 'label': 'car', 'confidence': 0.5270876, 'topleft': {'x': 240, 'y': 776}}, {'bottomright': {'x': 80, 'y': 954}, 'label': 'car', 'confidence': 0.32516766, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 540, 'y': 935}, 'label': 'car', 'confidence': 0.29572597, 'topleft': {'x': 400, 'y': 845}}, {'bottomright': {'x': 593, 'y': 932}, 'label': 'car', 'confidence': 0.29572535, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 548, 'y': 986}, 'label': 'car', 'confidence': 0.39615363, 'topleft': {'x': 397, 'y': 877}}, {'bottomright': {'x': 1887, 'y': 477}, 'label': 'traffic light', 'confidence': 0.33748817, 'topleft': {'x': 1858, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.0
# Elapsed time = 0.06673574447631836 s
# [{'bottomright': {'x': 880, 'y': 1075}, 'label': 'person', 'confidence': 0.31793642, 'topleft': {'x': 716, 'y': 928}}, {'bottomright': {'x': 1786, 'y': 630}, 'label': 'car', 'confidence': 0.5155305, 'topleft': {'x': 1692, 'y': 579}}, {'bottomright': {'x': 1818, 'y': 709}, 'label': 'car', 'confidence': 0.5471476, 'topleft': {'x': 1663, 'y': 614}}, {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.34942034, 'topleft': {'x': 156, 'y': 669}}, {'bottomright': {'x': 352, 'y': 810}, 'label': 'car', 'confidence': 0.46236295, 'topleft': {'x': 185, 'y': 724}}, {'bottomright': {'x': 1836, 'y': 894}, 'label': 'car', 'confidence': 0.8203585, 'topleft': {'x': 1618, 'y': 667}}, {'bottomright': {'x': 429, 'y': 863}, 'label': 'car', 'confidence': 0.5222671, 'topleft': {'x': 240, 'y': 776}}, {'bottomright': {'x': 81, 'y': 954}, 'label': 'car', 'confidence': 0.32618833, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 541, 'y': 934}, 'label': 'car', 'confidence': 0.2959141, 'topleft': {'x': 400, 'y': 846}}, {'bottomright': {'x': 594, 'y': 932}, 'label': 'car', 'confidence': 0.28819203, 'topleft': {'x': 475, 'y': 848}}, {'bottomright': {'x': 548, 'y': 985}, 'label': 'car', 'confidence': 0.3959957, 'topleft': {'x': 400, 'y': 878}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.3423838, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06574201583862305 s
# [{'bottomright': {'x': 882, 'y': 1078}, 'label': 'person', 'confidence': 0.35889706, 'topleft': {'x': 716, 'y': 927}}, {'bottomright': {'x': 1785, 'y': 629}, 'label': 'car', 'confidence': 0.47076097, 'topleft': {'x': 1695, 'y': 578}}, {'bottomright': {'x': 1807, 'y': 715}, 'label': 'car', 'confidence': 0.5812586, 'topleft': {'x': 1658, 'y': 609}}, {'bottomright': {'x': 317, 'y': 754}, 'label': 'car', 'confidence': 0.34407496, 'topleft': {'x': 157, 'y': 669}}, {'bottomright': {'x': 355, 'y': 810}, 'label': 'car', 'confidence': 0.461087, 'topleft': {'x': 187, 'y': 724}}, {'bottomright': {'x': 1835, 'y': 899}, 'label': 'car', 'confidence': 0.8338972, 'topleft': {'x': 1620, 'y': 664}}, {'bottomright': {'x': 428, 'y': 862}, 'label': 'car', 'confidence': 0.513214, 'topleft': {'x': 241, 'y': 776}}, {'bottomright': {'x': 82, 'y': 954}, 'label': 'car', 'confidence': 0.32256404, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 539, 'y': 933}, 'label': 'car', 'confidence': 0.27929723, 'topleft': {'x': 401, 'y': 846}}, {'bottomright': {'x': 594, 'y': 932}, 'label': 'car', 'confidence': 0.28825983, 'topleft': {'x': 477, 'y': 848}}, {'bottomright': {'x': 545, 'y': 986}, 'label': 'car', 'confidence': 0.38643396, 'topleft': {'x': 399, 'y': 878}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.32665583, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.1
# Elapsed time = 0.06606578826904297 s
# [{'bottomright': {'x': 880, 'y': 1076}, 'label': 'person', 'confidence': 0.29827803, 'topleft': {'x': 717, 'y': 928}}, {'bottomright': {'x': 1785, 'y': 627}, 'label': 'car', 'confidence': 0.4745191, 'topleft': {'x': 1692, 'y': 576}}, {'bottomright': {'x': 1807, 'y': 718}, 'label': 'car', 'confidence': 0.61151063, 'topleft': {'x': 1653, 'y': 603}}, {'bottomright': {'x': 316, 'y': 755}, 'label': 'car', 'confidence': 0.35100275, 'topleft': {'x': 156, 'y': 669}}, {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.4525719, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 430, 'y': 863}, 'label': 'car', 'confidence': 0.51901215, 'topleft': {'x': 240, 'y': 776}}, {'bottomright': {'x': 1848, 'y': 913}, 'label': 'car', 'confidence': 0.7478713, 'topleft': {'x': 1621, 'y': 689}}, {'bottomright': {'x': 83, 'y': 954}, 'label': 'car', 'confidence': 0.33248258, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 541, 'y': 934}, 'label': 'car', 'confidence': 0.2728445, 'topleft': {'x': 401, 'y': 846}}, {'bottomright': {'x': 594, 'y': 933}, 'label': 'car', 'confidence': 0.30192125, 'topleft': {'x': 476, 'y': 847}}, {'bottomright': {'x': 547, 'y': 986}, 'label': 'car', 'confidence': 0.38051578, 'topleft': {'x': 398, 'y': 877}}, {'bottomright': {'x': 179, 'y': 673}, 'label': 'motorbike', 'confidence': 0.2539106, 'topleft': {'x': 103, 'y': 621}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.3295543, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.9
# Elapsed time = 0.07186365127563477 s
# [{'bottomright': {'x': 882, 'y': 1077}, 'label': 'person', 'confidence': 0.34969032, 'topleft': {'x': 715, 'y': 927}}, {'bottomright': {'x': 1785, 'y': 631}, 'label': 'car', 'confidence': 0.47530633, 'topleft': {'x': 1692, 'y': 578}}, {'bottomright': {'x': 1801, 'y': 716}, 'label': 'car', 'confidence': 0.60141623, 'topleft': {'x': 1657, 'y': 604}}, {'bottomright': {'x': 316, 'y': 756}, 'label': 'car', 'confidence': 0.35926732, 'topleft': {'x': 155, 'y': 669}}, {'bottomright': {'x': 351, 'y': 809}, 'label': 'car', 'confidence': 0.44786584, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 428, 'y': 863}, 'label': 'car', 'confidence': 0.51270026, 'topleft': {'x': 241, 'y': 776}}, {'bottomright': {'x': 1855, 'y': 920}, 'label': 'car', 'confidence': 0.6897716, 'topleft': {'x': 1624, 'y': 683}}, {'bottomright': {'x': 82, 'y': 954}, 'label': 'car', 'confidence': 0.3302943, 'topleft': {'x': 0, 'y': 803}}, {'bottomright': {'x': 540, 'y': 934}, 'label': 'car', 'confidence': 0.2593959, 'topleft': {'x': 401, 'y': 846}}, {'bottomright': {'x': 595, 'y': 933}, 'label': 'car', 'confidence': 0.29363462, 'topleft': {'x': 477, 'y': 846}}, {'bottomright': {'x': 547, 'y': 986}, 'label': 'car', 'confidence': 0.38258463, 'topleft': {'x': 399, 'y': 877}}, {'bottomright': {'x': 1887, 'y': 478}, 'label': 'traffic light', 'confidence': 0.32482922, 'topleft': {'x': 1857, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06570672988891602 s
# [{'bottomright': {'x': 887, 'y': 1079}, 'label': 'person', 'confidence': 0.37484124, 'topleft': {'x': 711, 'y': 924}}, {'bottomright': {'x': 1787, 'y': 634}, 'label': 'car', 'confidence': 0.43698698, 'topleft': {'x': 1689, 'y': 579}}, {'bottomright': {'x': 1798, 'y': 710}, 'label': 'car', 'confidence': 0.48998666, 'topleft': {'x': 1652, 'y': 599}}, {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.32941672, 'topleft': {'x': 155, 'y': 667}}, {'bottomright': {'x': 355, 'y': 809}, 'label': 'car', 'confidence': 0.46960124, 'topleft': {'x': 188, 'y': 723}}, {'bottomright': {'x': 1859, 'y': 908}, 'label': 'car', 'confidence': 0.2991119, 'topleft': {'x': 1609, 'y': 612}}, {'bottomright': {'x': 434, 'y': 863}, 'label': 'car', 'confidence': 0.5246971, 'topleft': {'x': 241, 'y': 774}}, {'bottomright': {'x': 81, 'y': 954}, 'label': 'car', 'confidence': 0.31953517, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 539, 'y': 937}, 'label': 'car', 'confidence': 0.29832298, 'topleft': {'x': 394, 'y': 845}}, {'bottomright': {'x': 599, 'y': 935}, 'label': 'car', 'confidence': 0.26664856, 'topleft': {'x': 477, 'y': 846}}, {'bottomright': {'x': 554, 'y': 986}, 'label': 'car', 'confidence': 0.3879663, 'topleft': {'x': 398, 'y': 875}}, {'bottomright': {'x': 178, 'y': 673}, 'label': 'motorbike', 'confidence': 0.26996624, 'topleft': {'x': 104, 'y': 621}}, {'bottomright': {'x': 1851, 'y': 897}, 'label': 'motorbike', 'confidence': 0.555847, 'topleft': {'x': 1570, 'y': 618}}, {'bottomright': {'x': 1886, 'y': 477}, 'label': 'traffic light', 'confidence': 0.30849186, 'topleft': {'x': 1856, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.7
# Elapsed time = 0.06797266006469727 s
# [{'bottomright': {'x': 885, 'y': 1078}, 'label': 'person', 'confidence': 0.3768931, 'topleft': {'x': 712, 'y': 925}}, {'bottomright': {'x': 1786, 'y': 632}, 'label': 'car', 'confidence': 0.47298926, 'topleft': {'x': 1688, 'y': 580}}, {'bottomright': {'x': 1793, 'y': 702}, 'label': 'car', 'confidence': 0.48286697, 'topleft': {'x': 1654, 'y': 603}}, {'bottomright': {'x': 313, 'y': 753}, 'label': 'car', 'confidence': 0.34125724, 'topleft': {'x': 155, 'y': 668}}, {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.47036558, 'topleft': {'x': 190, 'y': 723}}, {'bottomright': {'x': 1873, 'y': 906}, 'label': 'car', 'confidence': 0.27778798, 'topleft': {'x': 1609, 'y': 620}}, {'bottomright': {'x': 431, 'y': 864}, 'label': 'car', 'confidence': 0.52359855, 'topleft': {'x': 242, 'y': 774}}, {'bottomright': {'x': 81, 'y': 955}, 'label': 'car', 'confidence': 0.3251543, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 596, 'y': 935}, 'label': 'car', 'confidence': 0.27051917, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 546, 'y': 986}, 'label': 'car', 'confidence': 0.38360903, 'topleft': {'x': 396, 'y': 876}}, {'bottomright': {'x': 179, 'y': 673}, 'label': 'motorbike', 'confidence': 0.26464695, 'topleft': {'x': 104, 'y': 621}}, {'bottomright': {'x': 1859, 'y': 901}, 'label': 'motorbike', 'confidence': 0.47474974, 'topleft': {'x': 1559, 'y': 615}}, {'bottomright': {'x': 1886, 'y': 477}, 'label': 'traffic light', 'confidence': 0.32567376, 'topleft': {'x': 1856, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.0
# Elapsed time = 0.06650972366333008 s
# [{'bottomright': {'x': 884, 'y': 1079}, 'label': 'person', 'confidence': 0.37497902, 'topleft': {'x': 712, 'y': 924}}, {'bottomright': {'x': 1784, 'y': 631}, 'label': 'car', 'confidence': 0.5521644, 'topleft': {'x': 1685, 'y': 581}}, {'bottomright': {'x': 1801, 'y': 702}, 'label': 'car', 'confidence': 0.7175306, 'topleft': {'x': 1619, 'y': 611}}, {'bottomright': {'x': 313, 'y': 752}, 'label': 'car', 'confidence': 0.34863892, 'topleft': {'x': 155, 'y': 668}}, {'bottomright': {'x': 354, 'y': 810}, 'label': 'car', 'confidence': 0.48498204, 'topleft': {'x': 189, 'y': 724}}, {'bottomright': {'x': 430, 'y': 865}, 'label': 'car', 'confidence': 0.5192209, 'topleft': {'x': 241, 'y': 773}}, {'bottomright': {'x': 1882, 'y': 920}, 'label': 'car', 'confidence': 0.5748244, 'topleft': {'x': 1632, 'y': 695}}, {'bottomright': {'x': 80, 'y': 955}, 'label': 'car', 'confidence': 0.3154106, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 597, 'y': 935}, 'label': 'car', 'confidence': 0.251248, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 551, 'y': 985}, 'label': 'car', 'confidence': 0.37809634, 'topleft': {'x': 396, 'y': 875}}, {'bottomright': {'x': 179, 'y': 673}, 'label': 'motorbike', 'confidence': 0.2592791, 'topleft': {'x': 104, 'y': 620}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.32383808, 'topleft': {'x': 1856, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.1
# Elapsed time = 0.06616568565368652 s
# [{'bottomright': {'x': 884, 'y': 1079}, 'label': 'person', 'confidence': 0.3934596, 'topleft': {'x': 712, 'y': 925}}, {'bottomright': {'x': 1401, 'y': 440}, 'label': 'car', 'confidence': 0.258887, 'topleft': {'x': 1364, 'y': 413}}, {'bottomright': {'x': 1785, 'y': 632}, 'label': 'car', 'confidence': 0.577718, 'topleft': {'x': 1683, 'y': 580}}, {'bottomright': {'x': 1803, 'y': 702}, 'label': 'car', 'confidence': 0.76021236, 'topleft': {'x': 1614, 'y': 610}}, {'bottomright': {'x': 314, 'y': 753}, 'label': 'car', 'confidence': 0.35268015, 'topleft': {'x': 155, 'y': 669}}, {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.47743586, 'topleft': {'x': 189, 'y': 723}}, {'bottomright': {'x': 434, 'y': 865}, 'label': 'car', 'confidence': 0.52429056, 'topleft': {'x': 239, 'y': 773}}, {'bottomright': {'x': 1886, 'y': 931}, 'label': 'car', 'confidence': 0.6737973, 'topleft': {'x': 1637, 'y': 692}}, {'bottomright': {'x': 80, 'y': 954}, 'label': 'car', 'confidence': 0.31388682, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 596, 'y': 934}, 'label': 'car', 'confidence': 0.25531676, 'topleft': {'x': 478, 'y': 847}}, {'bottomright': {'x': 549, 'y': 985}, 'label': 'car', 'confidence': 0.3884005, 'topleft': {'x': 395, 'y': 875}}, {'bottomright': {'x': 180, 'y': 673}, 'label': 'motorbike', 'confidence': 0.26713595, 'topleft': {'x': 103, 'y': 621}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.2969049, 'topleft': {'x': 1856, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 12.7
# Elapsed time = 0.07892704010009766 s
# [{'bottomright': {'x': 885, 'y': 1079}, 'label': 'person', 'confidence': 0.37312004, 'topleft': {'x': 712, 'y': 924}}, {'bottomright': {'x': 1401, 'y': 439}, 'label': 'car', 'confidence': 0.26936653, 'topleft': {'x': 1364, 'y': 413}}, {'bottomright': {'x': 1788, 'y': 633}, 'label': 'car', 'confidence': 0.5543569, 'topleft': {'x': 1682, 'y': 579}}, {'bottomright': {'x': 1809, 'y': 703}, 'label': 'car', 'confidence': 0.7856633, 'topleft': {'x': 1608, 'y': 615}}, {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.3574199, 'topleft': {'x': 153, 'y': 668}}, {'bottomright': {'x': 350, 'y': 808}, 'label': 'car', 'confidence': 0.47156453, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 404, 'y': 814}, 'label': 'car', 'confidence': 0.4365411, 'topleft': {'x': 248, 'y': 735}}, {'bottomright': {'x': 433, 'y': 865}, 'label': 'car', 'confidence': 0.5340281, 'topleft': {'x': 240, 'y': 774}}, {'bottomright': {'x': 1891, 'y': 934}, 'label': 'car', 'confidence': 0.68067825, 'topleft': {'x': 1641, 'y': 690}}, {'bottomright': {'x': 81, 'y': 954}, 'label': 'car', 'confidence': 0.3064146, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 595, 'y': 935}, 'label': 'car', 'confidence': 0.26871598, 'topleft': {'x': 479, 'y': 847}}, {'bottomright': {'x': 549, 'y': 985}, 'label': 'car', 'confidence': 0.3962656, 'topleft': {'x': 397, 'y': 875}}, {'bottomright': {'x': 180, 'y': 674}, 'label': 'motorbike', 'confidence': 0.25772, 'topleft': {'x': 103, 'y': 620}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.2896446, 'topleft': {'x': 1857, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.4
# Elapsed time = 0.0747063159942627 s
# [{'bottomright': {'x': 882, 'y': 1079}, 'label': 'person', 'confidence': 0.39141697, 'topleft': {'x': 713, 'y': 924}}, {'bottomright': {'x': 1401, 'y': 439}, 'label': 'car', 'confidence': 0.28029937, 'topleft': {'x': 1364, 'y': 412}}, {'bottomright': {'x': 1788, 'y': 632}, 'label': 'car', 'confidence': 0.5760251, 'topleft': {'x': 1682, 'y': 578}}, {'bottomright': {'x': 1801, 'y': 703}, 'label': 'car', 'confidence': 0.7708482, 'topleft': {'x': 1605, 'y': 615}}, {'bottomright': {'x': 314, 'y': 754}, 'label': 'car', 'confidence': 0.36536786, 'topleft': {'x': 153, 'y': 669}}, {'bottomright': {'x': 350, 'y': 809}, 'label': 'car', 'confidence': 0.47503254, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 433, 'y': 864}, 'label': 'car', 'confidence': 0.54135746, 'topleft': {'x': 241, 'y': 774}}, {'bottomright': {'x': 1887, 'y': 940}, 'label': 'car', 'confidence': 0.70964026, 'topleft': {'x': 1644, 'y': 689}}, {'bottomright': {'x': 81, 'y': 953}, 'label': 'car', 'confidence': 0.31006008, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 595, 'y': 934}, 'label': 'car', 'confidence': 0.2717309, 'topleft': {'x': 479, 'y': 847}}, {'bottomright': {'x': 550, 'y': 985}, 'label': 'car', 'confidence': 0.40162238, 'topleft': {'x': 398, 'y': 876}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.2861764, 'topleft': {'x': 1857, 'y': 446}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.3
# Elapsed time = 0.07501697540283203 s
# [{'bottomright': {'x': 882, 'y': 1077}, 'label': 'person', 'confidence': 0.31349123, 'topleft': {'x': 713, 'y': 926}}, {'bottomright': {'x': 1400, 'y': 438}, 'label': 'car', 'confidence': 0.26098257, 'topleft': {'x': 1362, 'y': 412}}, {'bottomright': {'x': 1788, 'y': 635}, 'label': 'car', 'confidence': 0.6041325, 'topleft': {'x': 1682, 'y': 578}}, {'bottomright': {'x': 1797, 'y': 700}, 'label': 'car', 'confidence': 0.7827638, 'topleft': {'x': 1594, 'y': 620}}, {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.35818538, 'topleft': {'x': 153, 'y': 669}}, {'bottomright': {'x': 351, 'y': 808}, 'label': 'car', 'confidence': 0.46661314, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 431, 'y': 864}, 'label': 'car', 'confidence': 0.52924454, 'topleft': {'x': 242, 'y': 774}}, {'bottomright': {'x': 1888, 'y': 946}, 'label': 'car', 'confidence': 0.7066776, 'topleft': {'x': 1646, 'y': 693}}, {'bottomright': {'x': 80, 'y': 953}, 'label': 'car', 'confidence': 0.3193547, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 596, 'y': 933}, 'label': 'car', 'confidence': 0.2613681, 'topleft': {'x': 480, 'y': 847}}, {'bottomright': {'x': 550, 'y': 985}, 'label': 'car', 'confidence': 0.3942976, 'topleft': {'x': 398, 'y': 875}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.29147857, 'topleft': {'x': 1857, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.4
# Elapsed time = 0.07448005676269531 s
# [{'bottomright': {'x': 881, 'y': 1077}, 'label': 'person', 'confidence': 0.340189, 'topleft': {'x': 715, 'y': 926}}, {'bottomright': {'x': 1401, 'y': 438}, 'label': 'car', 'confidence': 0.2658675, 'topleft': {'x': 1363, 'y': 412}}, {'bottomright': {'x': 1787, 'y': 634}, 'label': 'car', 'confidence': 0.55703783, 'topleft': {'x': 1686, 'y': 578}}, {'bottomright': {'x': 1786, 'y': 698}, 'label': 'car', 'confidence': 0.78268474, 'topleft': {'x': 1585, 'y': 618}}, {'bottomright': {'x': 315, 'y': 753}, 'label': 'car', 'confidence': 0.34808204, 'topleft': {'x': 155, 'y': 668}}, {'bottomright': {'x': 349, 'y': 808}, 'label': 'car', 'confidence': 0.45990917, 'topleft': {'x': 187, 'y': 723}}, {'bottomright': {'x': 430, 'y': 865}, 'label': 'car', 'confidence': 0.5196319, 'topleft': {'x': 242, 'y': 774}}, {'bottomright': {'x': 1893, 'y': 944}, 'label': 'car', 'confidence': 0.7269669, 'topleft': {'x': 1653, 'y': 699}}, {'bottomright': {'x': 80, 'y': 952}, 'label': 'car', 'confidence': 0.3265029, 'topleft': {'x': 0, 'y': 802}}, {'bottomright': {'x': 535, 'y': 937}, 'label': 'car', 'confidence': 0.2681784, 'topleft': {'x': 395, 'y': 846}}, {'bottomright': {'x': 550, 'y': 986}, 'label': 'car', 'confidence': 0.40218908, 'topleft': {'x': 397, 'y': 876}}, {'bottomright': {'x': 1886, 'y': 477}, 'label': 'traffic light', 'confidence': 0.30537322, 'topleft': {'x': 1856, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.9
# Elapsed time = 0.06696534156799316 s
# [{'bottomright': {'x': 877, 'y': 1076}, 'label': 'person', 'confidence': 0.29171222, 'topleft': {'x': 720, 'y': 929}}, {'bottomright': {'x': 1404, 'y': 439}, 'label': 'car', 'confidence': 0.28032014, 'topleft': {'x': 1366, 'y': 411}}, {'bottomright': {'x': 1789, 'y': 636}, 'label': 'car', 'confidence': 0.528449, 'topleft': {'x': 1693, 'y': 579}}, {'bottomright': {'x': 1777, 'y': 697}, 'label': 'car', 'confidence': 0.77972853, 'topleft': {'x': 1580, 'y': 617}}, {'bottomright': {'x': 312, 'y': 753}, 'label': 'car', 'confidence': 0.37836057, 'topleft': {'x': 152, 'y': 671}}, {'bottomright': {'x': 350, 'y': 809}, 'label': 'car', 'confidence': 0.46887404, 'topleft': {'x': 186, 'y': 724}}, {'bottomright': {'x': 434, 'y': 863}, 'label': 'car', 'confidence': 0.54351497, 'topleft': {'x': 240, 'y': 773}}, {'bottomright': {'x': 1899, 'y': 946}, 'label': 'car', 'confidence': 0.6796981, 'topleft': {'x': 1656, 'y': 700}}, {'bottomright': {'x': 79, 'y': 954}, 'label': 'car', 'confidence': 0.30708715, 'topleft': {'x': 0, 'y': 800}}, {'bottomright': {'x': 534, 'y': 936}, 'label': 'car', 'confidence': 0.3101538, 'topleft': {'x': 394, 'y': 844}}, {'bottomright': {'x': 601, 'y': 934}, 'label': 'car', 'confidence': 0.27844337, 'topleft': {'x': 483, 'y': 845}}, {'bottomright': {'x': 548, 'y': 986}, 'label': 'car', 'confidence': 0.4229452, 'topleft': {'x': 395, 'y': 875}}, {'bottomright': {'x': 1886, 'y': 478}, 'label': 'traffic light', 'confidence': 0.312885, 'topleft': {'x': 1854, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 13.1
# Elapsed time = 0.0760648250579834 s
# [{'bottomright': {'x': 877, 'y': 1076}, 'label': 'person', 'confidence': 0.29428375, 'topleft': {'x': 719, 'y': 930}}, {'bottomright': {'x': 1788, 'y': 635}, 'label': 'car', 'confidence': 0.4909807, 'topleft': {'x': 1692, 'y': 579}}, {'bottomright': {'x': 1773, 'y': 696}, 'label': 'car', 'confidence': 0.75975, 'topleft': {'x': 1573, 'y': 619}}, {'bottomright': {'x': 312, 'y': 754}, 'label': 'car', 'confidence': 0.36704013, 'topleft': {'x': 153, 'y': 671}}, {'bottomright': {'x': 353, 'y': 810}, 'label': 'car', 'confidence': 0.47286704, 'topleft': {'x': 188, 'y': 724}}, {'bottomright': {'x': 432, 'y': 863}, 'label': 'car', 'confidence': 0.5292638, 'topleft': {'x': 240, 'y': 773}}, {'bottomright': {'x': 1901, 'y': 949}, 'label': 'car', 'confidence': 0.69700634, 'topleft': {'x': 1660, 'y': 699}}, {'bottomright': {'x': 78, 'y': 955}, 'label': 'car', 'confidence': 0.32193527, 'topleft': {'x': 0, 'y': 800}}, {'bottomright': {'x': 536, 'y': 936}, 'label': 'car', 'confidence': 0.3110536, 'topleft': {'x': 393, 'y': 844}}, {'bottomright': {'x': 603, 'y': 934}, 'label': 'car', 'confidence': 0.26902488, 'topleft': {'x': 481, 'y': 846}}, {'bottomright': {'x': 550, 'y': 986}, 'label': 'car', 'confidence': 0.43637756, 'topleft': {'x': 394, 'y': 876}}, {'bottomright': {'x': 1885, 'y': 479}, 'label': 'traffic light', 'confidence': 0.27411637, 'topleft': {'x': 1854, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 12.9
# Elapsed time = 0.07775664329528809 s
# [{'bottomright': {'x': 877, 'y': 1076}, 'label': 'person', 'confidence': 0.27881527, 'topleft': {'x': 721, 'y': 930}}, {'bottomright': {'x': 1400, 'y': 439}, 'label': 'car', 'confidence': 0.28461254, 'topleft': {'x': 1364, 'y': 411}}, {'bottomright': {'x': 1790, 'y': 654}, 'label': 'car', 'confidence': 0.53387386, 'topleft': {'x': 1686, 'y': 580}}, {'bottomright': {'x': 1759, 'y': 700}, 'label': 'car', 'confidence': 0.754118, 'topleft': {'x': 1562, 'y': 617}}, {'bottomright': {'x': 313, 'y': 755}, 'label': 'car', 'confidence': 0.36571833, 'topleft': {'x': 152, 'y': 671}}, {'bottomright': {'x': 353, 'y': 810}, 'label': 'car', 'confidence': 0.47848505, 'topleft': {'x': 188, 'y': 725}}, {'bottomright': {'x': 532, 'y': 809}, 'label': 'car', 'confidence': 0.2647787, 'topleft': {'x': 395, 'y': 728}}, {'bottomright': {'x': 432, 'y': 864}, 'label': 'car', 'confidence': 0.5392281, 'topleft': {'x': 242, 'y': 773}}, {'bottomright': {'x': 1907, 'y': 953}, 'label': 'car', 'confidence': 0.6712381, 'topleft': {'x': 1669, 'y': 703}}, {'bottomright': {'x': 80, 'y': 953}, 'label': 'car', 'confidence': 0.29719135, 'topleft': {'x': 0, 'y': 800}}, {'bottomright': {'x': 533, 'y': 935}, 'label': 'car', 'confidence': 0.339526, 'topleft': {'x': 394, 'y': 843}}, {'bottomright': {'x': 603, 'y': 933}, 'label': 'car', 'confidence': 0.30940822, 'topleft': {'x': 482, 'y': 845}}, {'bottomright': {'x': 546, 'y': 986}, 'label': 'car', 'confidence': 0.43832353, 'topleft': {'x': 396, 'y': 877}}, {'bottomright': {'x': 1885, 'y': 478}, 'label': 'traffic light', 'confidence': 0.26798362, 'topleft': {'x': 1853, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 11.6
# Elapsed time = 0.0858607292175293 s
# [{'bottomright': {'x': 877, 'y': 1077}, 'label': 'person', 'confidence': 0.30448455, 'topleft': {'x': 720, 'y': 929}}, {'bottomright': {'x': 1400, 'y': 438}, 'label': 'car', 'confidence': 0.2633213, 'topleft': {'x': 1364, 'y': 411}}, {'bottomright': {'x': 1790, 'y': 638}, 'label': 'car', 'confidence': 0.538088, 'topleft': {'x': 1695, 'y': 580}}, {'bottomright': {'x': 1748, 'y': 699}, 'label': 'car', 'confidence': 0.74409044, 'topleft': {'x': 1560, 'y': 616}}, {'bottomright': {'x': 313, 'y': 755}, 'label': 'car', 'confidence': 0.3587551, 'topleft': {'x': 154, 'y': 671}}, {'bottomright': {'x': 353, 'y': 809}, 'label': 'car', 'confidence': 0.47148034, 'topleft': {'x': 190, 'y': 724}}, {'bottomright': {'x': 531, 'y': 807}, 'label': 'car', 'confidence': 0.27813187, 'topleft': {'x': 394, 'y': 728}}, {'bottomright': {'x': 430, 'y': 863}, 'label': 'car', 'confidence': 0.5325453, 'topleft': {'x': 241, 'y': 773}}, {'bottomright': {'x': 1903, 'y': 935}, 'label': 'car', 'confidence': 0.6634262, 'topleft': {'x': 1684, 'y': 720}}, {'bottomright': {'x': 80, 'y': 954}, 'label': 'car', 'confidence': 0.30490515, 'topleft': {'x': 0, 'y': 799}}, {'bottomright': {'x': 534, 'y': 935}, 'label': 'car', 'confidence': 0.35203543, 'topleft': {'x': 394, 'y': 843}}, {'bottomright': {'x': 604, 'y': 933}, 'label': 'car', 'confidence': 0.32519343, 'topleft': {'x': 482, 'y': 846}}, {'bottomright': {'x': 546, 'y': 985}, 'label': 'car', 'confidence': 0.43738574, 'topleft': {'x': 395, 'y': 876}}, {'bottomright': {'x': 179, 'y': 674}, 'label': 'motorbike', 'confidence': 0.25114456, 'topleft': {'x': 103, 'y': 621}}, {'bottomright': {'x': 1884, 'y': 478}, 'label': 'traffic light', 'confidence': 0.26856747, 'topleft': {'x': 1853, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06590580940246582 s
# [{'bottomright': {'x': 879, 'y': 1078}, 'label': 'person', 'confidence': 0.37018508, 'topleft': {'x': 718, 'y': 927}}, {'bottomright': {'x': 1401, 'y': 439}, 'label': 'car', 'confidence': 0.27261358, 'topleft': {'x': 1364, 'y': 412}}, {'bottomright': {'x': 1791, 'y': 653}, 'label': 'car', 'confidence': 0.5550194, 'topleft': {'x': 1686, 'y': 580}}, {'bottomright': {'x': 1740, 'y': 699}, 'label': 'car', 'confidence': 0.7508276, 'topleft': {'x': 1552, 'y': 617}}, {'bottomright': {'x': 312, 'y': 754}, 'label': 'car', 'confidence': 0.38373753, 'topleft': {'x': 152, 'y': 672}}, {'bottomright': {'x': 354, 'y': 809}, 'label': 'car', 'confidence': 0.48170325, 'topleft': {'x': 189, 'y': 724}}, {'bottomright': {'x': 529, 'y': 809}, 'label': 'car', 'confidence': 0.28376624, 'topleft': {'x': 393, 'y': 729}}, {'bottomright': {'x': 431, 'y': 864}, 'label': 'car', 'confidence': 0.53961563, 'topleft': {'x': 241, 'y': 774}}, {'bottomright': {'x': 1907, 'y': 938}, 'label': 'car', 'confidence': 0.6686523, 'topleft': {'x': 1687, 'y': 716}}, {'bottomright': {'x': 80, 'y': 954}, 'label': 'car', 'confidence': 0.33564818, 'topleft': {'x': 0, 'y': 799}}, {'bottomright': {'x': 535, 'y': 935}, 'label': 'car', 'confidence': 0.35215408, 'topleft': {'x': 393, 'y': 843}}, {'bottomright': {'x': 603, 'y': 934}, 'label': 'car', 'confidence': 0.33584496, 'topleft': {'x': 480, 'y': 845}}, {'bottomright': {'x': 545, 'y': 986}, 'label': 'car', 'confidence': 0.4439535, 'topleft': {'x': 395, 'y': 876}}, {'bottomright': {'x': 1884, 'y': 478}, 'label': 'traffic light', 'confidence': 0.267778, 'topleft': {'x': 1853, 'y': 444}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06562113761901855 s
# [{'bottomright': {'x': 879, 'y': 1078}, 'label': 'person', 'confidence': 0.36442664, 'topleft': {'x': 719, 'y': 928}}, {'bottomright': {'x': 1402, 'y': 439}, 'label': 'car', 'confidence': 0.27888328, 'topleft': {'x': 1365, 'y': 412}}, {'bottomright': {'x': 1793, 'y': 654}, 'label': 'car', 'confidence': 0.57262456, 'topleft': {'x': 1685, 'y': 579}}, {'bottomright': {'x': 1732, 'y': 697}, 'label': 'car', 'confidence': 0.71763533, 'topleft': {'x': 1545, 'y': 611}}, {'bottomright': {'x': 312, 'y': 754}, 'label': 'car', 'confidence': 0.36015517, 'topleft': {'x': 154, 'y': 672}}, {'bottomright': {'x': 352, 'y': 809}, 'label': 'car', 'confidence': 0.4664318, 'topleft': {'x': 189, 'y': 724}}, {'bottomright': {'x': 529, 'y': 809}, 'label': 'car', 'confidence': 0.27479196, 'topleft': {'x': 393, 'y': 729}}, {'bottomright': {'x': 432, 'y': 863}, 'label': 'car', 'confidence': 0.5300942, 'topleft': {'x': 243, 'y': 774}}, {'bottomright': {'x': 1919, 'y': 931}, 'label': 'car', 'confidence': 0.68129563, 'topleft': {'x': 1688, 'y': 723}}, {'bottomright': {'x': 81, 'y': 954}, 'label': 'car', 'confidence': 0.361212, 'topleft': {'x': 0, 'y': 799}}, {'bottomright': {'x': 535, 'y': 936}, 'label': 'car', 'confidence': 0.33062983, 'topleft': {'x': 393, 'y': 842}}, {'bottomright': {'x': 602, 'y': 934}, 'label': 'car', 'confidence': 0.32951456, 'topleft': {'x': 480, 'y': 845}}, {'bottomright': {'x': 545, 'y': 986}, 'label': 'car', 'confidence': 0.41993603, 'topleft': {'x': 395, 'y': 876}}, {'bottomright': {'x': 179, 'y': 674}, 'label': 'motorbike', 'confidence': 0.25898102, 'topleft': {'x': 103, 'y': 621}}, {'bottomright': {'x': 1885, 'y': 478}, 'label': 'traffic light', 'confidence': 0.26961386, 'topleft': {'x': 1853, 'y': 445}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.3
# Elapsed time = 0.06549644470214844 s
# ...
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.1
# Elapsed time = 0.06612348556518555 s
# [{'bottomright': {'x': 877, 'y': 1079}, 'label': 'person', 'confidence': 0.43094894, 'topleft': {'x': 710, 'y': 920}}, {'bottomright': {'x': 994, 'y': 375}, 'label': 'car', 'confidence': 0.43365955, 'topleft': {'x': 936, 'y': 348}}, {'bottomright': {'x': 1101, 'y': 418}, 'label': 'car', 'confidence': 0.47845396, 'topleft': {'x': 1040, 'y': 384}}, {'bottomright': {'x': 1256, 'y': 429}, 'label': 'car', 'confidence': 0.41939285, 'topleft': {'x': 1204, 'y': 403}}, {'bottomright': {'x': 1403, 'y': 436}, 'label': 'car', 'confidence': 0.25068143, 'topleft': {'x': 1367, 'y': 411}}, {'bottomright': {'x': 1796, 'y': 655}, 'label': 'car', 'confidence': 0.37528965, 'topleft': {'x': 1669, 'y': 583}}, {'bottomright': {'x': 317, 'y': 754}, 'label': 'car', 'confidence': 0.36766925, 'topleft': {'x': 161, 'y': 667}}, {'bottomright': {'x': 1870, 'y': 738}, 'label': 'car', 'confidence': 0.64264137, 'topleft': {'x': 1705, 'y': 651}}, {'bottomright': {'x': 405, 'y': 817}, 'label': 'car', 'confidence': 0.47283325, 'topleft': {'x': 241, 'y': 734}}, {'bottomright': {'x': 541, 'y': 803}, 'label': 'car', 'confidence': 0.30160403, 'topleft': {'x': 403, 'y': 719}}, {'bottomright': {'x': 427, 'y': 862}, 'label': 'car', 'confidence': 0.53545564, 'topleft': {'x': 252, 'y': 775}}, {'bottomright': {'x': 78, 'y': 962}, 'label': 'car', 'confidence': 0.3104704, 'topleft': {'x': 0, 'y': 794}}, {'bottomright': {'x': 540, 'y': 943}, 'label': 'car', 'confidence': 0.36159536, 'topleft': {'x': 394, 'y': 838}}, {'bottomright': {'x': 605, 'y': 948}, 'label': 'car', 'confidence': 0.30613127, 'topleft': {'x': 470, 'y': 843}}, {'bottomright': {'x': 1879, 'y': 467}, 'label': 'traffic light', 'confidence': 0.27970505, 'topleft': {'x': 1849, 'y': 431}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.0
# Elapsed time = 0.06651115417480469 s
# [{'bottomright': {'x': 878, 'y': 1079}, 'label': 'person', 'confidence': 0.3854849, 'topleft': {'x': 709, 'y': 918}}, {'bottomright': {'x': 439, 'y': 368}, 'label': 'car', 'confidence': 0.2667912, 'topleft': {'x': 394, 'y': 343}}, {'bottomright': {'x': 996, 'y': 376}, 'label': 'car', 'confidence': 0.4472182, 'topleft': {'x': 938, 'y': 348}}, {'bottomright': {'x': 1101, 'y': 418}, 'label': 'car', 'confidence': 0.42171574, 'topleft': {'x': 1043, 'y': 384}}, {'bottomright': {'x': 1256, 'y': 429}, 'label': 'car', 'confidence': 0.42634082, 'topleft': {'x': 1206, 'y': 404}}, {'bottomright': {'x': 1400, 'y': 437}, 'label': 'car', 'confidence': 0.27253932, 'topleft': {'x': 1365, 'y': 412}}, {'bottomright': {'x': 1797, 'y': 655}, 'label': 'car', 'confidence': 0.4356208, 'topleft': {'x': 1668, 'y': 583}}, {'bottomright': {'x': 317, 'y': 753}, 'label': 'car', 'confidence': 0.39785367, 'topleft': {'x': 159, 'y': 667}}, {'bottomright': {'x': 1871, 'y': 739}, 'label': 'car', 'confidence': 0.6555294, 'topleft': {'x': 1704, 'y': 651}}, {'bottomright': {'x': 408, 'y': 818}, 'label': 'car', 'confidence': 0.48137465, 'topleft': {'x': 240, 'y': 734}}, {'bottomright': {'x': 539, 'y': 801}, 'label': 'car', 'confidence': 0.2641863, 'topleft': {'x': 401, 'y': 720}}, {'bottomright': {'x': 428, 'y': 861}, 'label': 'car', 'confidence': 0.53629243, 'topleft': {'x': 249, 'y': 774}}, {'bottomright': {'x': 78, 'y': 962}, 'label': 'car', 'confidence': 0.31340927, 'topleft': {'x': 0, 'y': 794}}, {'bottomright': {'x': 541, 'y': 943}, 'label': 'car', 'confidence': 0.36407092, 'topleft': {'x': 394, 'y': 837}}, {'bottomright': {'x': 605, 'y': 948}, 'label': 'car', 'confidence': 0.33280218, 'topleft': {'x': 470, 'y': 842}}, {'bottomright': {'x': 1880, 'y': 467}, 'label': 'traffic light', 'confidence': 0.3106115, 'topleft': {'x': 1849, 'y': 432}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.1
# Elapsed time = 0.06645607948303223 s
# [{'bottomright': {'x': 877, 'y': 1079}, 'label': 'person', 'confidence': 0.34299606, 'topleft': {'x': 709, 'y': 922}}, {'bottomright': {'x': 439, 'y': 368}, 'label': 'car', 'confidence': 0.2825807, 'topleft': {'x': 393, 'y': 342}}, {'bottomright': {'x': 997, 'y': 376}, 'label': 'car', 'confidence': 0.45485052, 'topleft': {'x': 939, 'y': 348}}, {'bottomright': {'x': 1099, 'y': 417}, 'label': 'car', 'confidence': 0.42214784, 'topleft': {'x': 1041, 'y': 386}}, {'bottomright': {'x': 1257, 'y': 427}, 'label': 'car', 'confidence': 0.4220835, 'topleft': {'x': 1210, 'y': 403}}, {'bottomright': {'x': 1400, 'y': 437}, 'label': 'car', 'confidence': 0.2595285, 'topleft': {'x': 1365, 'y': 413}}, {'bottomright': {'x': 1796, 'y': 655}, 'label': 'car', 'confidence': 0.4515433, 'topleft': {'x': 1668, 'y': 584}}, {'bottomright': {'x': 316, 'y': 753}, 'label': 'car', 'confidence': 0.3980698, 'topleft': {'x': 162, 'y': 667}}, {'bottomright': {'x': 1871, 'y': 740}, 'label': 'car', 'confidence': 0.6531425, 'topleft': {'x': 1702, 'y': 650}}, {'bottomright': {'x': 407, 'y': 818}, 'label': 'car', 'confidence': 0.48405722, 'topleft': {'x': 241, 'y': 734}}, {'bottomright': {'x': 537, 'y': 801}, 'label': 'car', 'confidence': 0.26509637, 'topleft': {'x': 402, 'y': 720}}, {'bottomright': {'x': 426, 'y': 860}, 'label': 'car', 'confidence': 0.5212922, 'topleft': {'x': 250, 'y': 774}}, {'bottomright': {'x': 77, 'y': 961}, 'label': 'car', 'confidence': 0.28764006, 'topleft': {'x': 0, 'y': 795}}, {'bottomright': {'x': 540, 'y': 942}, 'label': 'car', 'confidence': 0.34639308, 'topleft': {'x': 394, 'y': 838}}, {'bottomright': {'x': 606, 'y': 948}, 'label': 'car', 'confidence': 0.31425756, 'topleft': {'x': 472, 'y': 842}}, {'bottomright': {'x': 1880, 'y': 467}, 'label': 'traffic light', 'confidence': 0.30859756, 'topleft': {'x': 1850, 'y': 432}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06589198112487793 s
# [{'bottomright': {'x': 877, 'y': 1079}, 'label': 'person', 'confidence': 0.42154858, 'topleft': {'x': 704, 'y': 920}}, {'bottomright': {'x': 1000, 'y': 376}, 'label': 'car', 'confidence': 0.4590585, 'topleft': {'x': 939, 'y': 349}}, {'bottomright': {'x': 1098, 'y': 417}, 'label': 'car', 'confidence': 0.47684005, 'topleft': {'x': 1042, 'y': 387}}, {'bottomright': {'x': 1260, 'y': 427}, 'label': 'car', 'confidence': 0.44163066, 'topleft': {'x': 1212, 'y': 403}}, {'bottomright': {'x': 1401, 'y': 437}, 'label': 'car', 'confidence': 0.25172195, 'topleft': {'x': 1366, 'y': 413}}, {'bottomright': {'x': 1776, 'y': 635}, 'label': 'car', 'confidence': 0.40063182, 'topleft': {'x': 1696, 'y': 579}}, {'bottomright': {'x': 1814, 'y': 709}, 'label': 'car', 'confidence': 0.29421884, 'topleft': {'x': 1671, 'y': 601}}, {'bottomright': {'x': 317, 'y': 754}, 'label': 'car', 'confidence': 0.3730616, 'topleft': {'x': 161, 'y': 669}}, {'bottomright': {'x': 1873, 'y': 739}, 'label': 'car', 'confidence': 0.6303988, 'topleft': {'x': 1702, 'y': 652}}, {'bottomright': {'x': 406, 'y': 817}, 'label': 'car', 'confidence': 0.5013227, 'topleft': {'x': 241, 'y': 737}}, {'bottomright': {'x': 425, 'y': 862}, 'label': 'car', 'confidence': 0.5455037, 'topleft': {'x': 248, 'y': 776}}, {'bottomright': {'x': 78, 'y': 958}, 'label': 'car', 'confidence': 0.29312193, 'topleft': {'x': 0, 'y': 798}}, {'bottomright': {'x': 602, 'y': 945}, 'label': 'car', 'confidence': 0.26256868, 'topleft': {'x': 468, 'y': 846}}, {'bottomright': {'x': 552, 'y': 979}, 'label': 'car', 'confidence': 0.38177004, 'topleft': {'x': 412, 'y': 874}}, {'bottomright': {'x': 1881, 'y': 468}, 'label': 'traffic light', 'confidence': 0.31806257, 'topleft': {'x': 1850, 'y': 431}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.6
# Elapsed time = 0.06854772567749023 s
# [{'bottomright': {'x': 876, 'y': 1079}, 'label': 'person', 'confidence': 0.39564803, 'topleft': {'x': 705, 'y': 920}}, {'bottomright': {'x': 1000, 'y': 374}, 'label': 'car', 'confidence': 0.4804657, 'topleft': {'x': 937, 'y': 347}}, {'bottomright': {'x': 1102, 'y': 418}, 'label': 'car', 'confidence': 0.48065546, 'topleft': {'x': 1049, 'y': 384}}, {'bottomright': {'x': 1258, 'y': 427}, 'label': 'car', 'confidence': 0.31059098, 'topleft': {'x': 1218, 'y': 403}}, {'bottomright': {'x': 1777, 'y': 636}, 'label': 'car', 'confidence': 0.39442885, 'topleft': {'x': 1697, 'y': 579}}, {'bottomright': {'x': 1816, 'y': 708}, 'label': 'car', 'confidence': 0.28440896, 'topleft': {'x': 1672, 'y': 601}}, {'bottomright': {'x': 317, 'y': 754}, 'label': 'car', 'confidence': 0.38312376, 'topleft': {'x': 163, 'y': 669}}, {'bottomright': {'x': 1871, 'y': 739}, 'label': 'car', 'confidence': 0.62724715, 'topleft': {'x': 1699, 'y': 652}}, {'bottomright': {'x': 409, 'y': 818}, 'label': 'car', 'confidence': 0.49988958, 'topleft': {'x': 241, 'y': 737}}, {'bottomright': {'x': 428, 'y': 862}, 'label': 'car', 'confidence': 0.55042225, 'topleft': {'x': 248, 'y': 777}}, {'bottomright': {'x': 78, 'y': 957}, 'label': 'car', 'confidence': 0.28559923, 'topleft': {'x': 0, 'y': 798}}, {'bottomright': {'x': 541, 'y': 941}, 'label': 'car', 'confidence': 0.37341657, 'topleft': {'x': 392, 'y': 840}}, {'bottomright': {'x': 604, 'y': 945}, 'label': 'car', 'confidence': 0.27656958, 'topleft': {'x': 469, 'y': 846}}, {'bottomright': {'x': 1880, 'y': 468}, 'label': 'traffic light', 'confidence': 0.30423328, 'topleft': {'x': 1849, 'y': 432}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06592369079589844 s
# [{'bottomright': {'x': 878, 'y': 1079}, 'label': 'person', 'confidence': 0.432211, 'topleft': {'x': 707, 'y': 919}}, {'bottomright': {'x': 999, 'y': 373}, 'label': 'car', 'confidence': 0.45308417, 'topleft': {'x': 937, 'y': 346}}, {'bottomright': {'x': 1100, 'y': 417}, 'label': 'car', 'confidence': 0.45731592, 'topleft': {'x': 1051, 'y': 385}}, {'bottomright': {'x': 1260, 'y': 425}, 'label': 'car', 'confidence': 0.31857735, 'topleft': {'x': 1220, 'y': 402}}, {'bottomright': {'x': 1778, 'y': 636}, 'label': 'car', 'confidence': 0.4282159, 'topleft': {'x': 1696, 'y': 579}}, {'bottomright': {'x': 1809, 'y': 706}, 'label': 'car', 'confidence': 0.27448854, 'topleft': {'x': 1673, 'y': 600}}, {'bottomright': {'x': 321, 'y': 755}, 'label': 'car', 'confidence': 0.36349395, 'topleft': {'x': 165, 'y': 669}}, {'bottomright': {'x': 1876, 'y': 740}, 'label': 'car', 'confidence': 0.6144472, 'topleft': {'x': 1705, 'y': 651}}, {'bottomright': {'x': 408, 'y': 817}, 'label': 'car', 'confidence': 0.47631493, 'topleft': {'x': 239, 'y': 736}}, {'bottomright': {'x': 428, 'y': 863}, 'label': 'car', 'confidence': 0.5502707, 'topleft': {'x': 250, 'y': 778}}, {'bottomright': {'x': 78, 'y': 960}, 'label': 'car', 'confidence': 0.29052916, 'topleft': {'x': 0, 'y': 796}}, {'bottomright': {'x': 604, 'y': 946}, 'label': 'car', 'confidence': 0.2581218, 'topleft': {'x': 470, 'y': 845}}, {'bottomright': {'x': 553, 'y': 978}, 'label': 'car', 'confidence': 0.37362683, 'topleft': {'x': 410, 'y': 874}}, {'bottomright': {'x': 1881, 'y': 468}, 'label': 'traffic light', 'confidence': 0.28918427, 'topleft': {'x': 1849, 'y': 431}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.8
# Elapsed time = 0.06764841079711914 s
# [{'bottomright': {'x': 878, 'y': 1079}, 'label': 'person', 'confidence': 0.43830264, 'topleft': {'x': 707, 'y': 917}}, {'bottomright': {'x': 999, 'y': 374}, 'label': 'car', 'confidence': 0.44904304, 'topleft': {'x': 938, 'y': 347}}, {'bottomright': {'x': 1099, 'y': 417}, 'label': 'car', 'confidence': 0.50126034, 'topleft': {'x': 1048, 'y': 384}}, {'bottomright': {'x': 1266, 'y': 424}, 'label': 'car', 'confidence': 0.33745477, 'topleft': {'x': 1225, 'y': 400}}, {'bottomright': {'x': 1778, 'y': 637}, 'label': 'car', 'confidence': 0.44062597, 'topleft': {'x': 1696, 'y': 579}}, {'bottomright': {'x': 1810, 'y': 704}, 'label': 'car', 'confidence': 0.27384588, 'topleft': {'x': 1672, 'y': 600}}, {'bottomright': {'x': 320, 'y': 755}, 'label': 'car', 'confidence': 0.37460223, 'topleft': {'x': 164, 'y': 670}}, {'bottomright': {'x': 1875, 'y': 739}, 'label': 'car', 'confidence': 0.6276269, 'topleft': {'x': 1704, 'y': 652}}, {'bottomright': {'x': 408, 'y': 817}, 'label': 'car', 'confidence': 0.48216859, 'topleft': {'x': 239, 'y': 736}}, {'bottomright': {'x': 428, 'y': 863}, 'label': 'car', 'confidence': 0.5592996, 'topleft': {'x': 251, 'y': 778}}, {'bottomright': {'x': 78, 'y': 959}, 'label': 'car', 'confidence': 0.26540896, 'topleft': {'x': 0, 'y': 797}}, {'bottomright': {'x': 553, 'y': 978}, 'label': 'car', 'confidence': 0.36945856, 'topleft': {'x': 411, 'y': 874}}, {'bottomright': {'x': 1881, 'y': 468}, 'label': 'traffic light', 'confidence': 0.2731566, 'topleft': {'x': 1849, 'y': 431}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 14.9
# Elapsed time = 0.0672917366027832 s
# [{'bottomright': {'x': 879, 'y': 1079}, 'label': 'person', 'confidence': 0.43418324, 'topleft': {'x': 710, 'y': 917}}, {'bottomright': {'x': 442, 'y': 367}, 'label': 'car', 'confidence': 0.2590783, 'topleft': {'x': 389, 'y': 340}}, {'bottomright': {'x': 997, 'y': 374}, 'label': 'car', 'confidence': 0.4372959, 'topleft': {'x': 937, 'y': 346}}, {'bottomright': {'x': 1100, 'y': 418}, 'label': 'car', 'confidence': 0.47984776, 'topleft': {'x': 1049, 'y': 383}}, {'bottomright': {'x': 1264, 'y': 424}, 'label': 'car', 'confidence': 0.2974938, 'topleft': {'x': 1225, 'y': 399}}, {'bottomright': {'x': 1777, 'y': 636}, 'label': 'car', 'confidence': 0.42463374, 'topleft': {'x': 1696, 'y': 579}}, {'bottomright': {'x': 1809, 'y': 706}, 'label': 'car', 'confidence': 0.2618983, 'topleft': {'x': 1673, 'y': 600}}, {'bottomright': {'x': 320, 'y': 755}, 'label': 'car', 'confidence': 0.37248725, 'topleft': {'x': 164, 'y': 669}}, {'bottomright': {'x': 1871, 'y': 739}, 'label': 'car', 'confidence': 0.61368316, 'topleft': {'x': 1703, 'y': 651}}, {'bottomright': {'x': 407, 'y': 817}, 'label': 'car', 'confidence': 0.44250494, 'topleft': {'x': 242, 'y': 735}}, {'bottomright': {'x': 426, 'y': 864}, 'label': 'car', 'confidence': 0.54749435, 'topleft': {'x': 252, 'y': 778}}, {'bottomright': {'x': 79, 'y': 961}, 'label': 'car', 'confidence': 0.28014055, 'topleft': {'x': 0, 'y': 794}}, {'bottomright': {'x': 542, 'y': 942}, 'label': 'car', 'confidence': 0.36511204, 'topleft': {'x': 392, 'y': 842}}, {'bottomright': {'x': 1882, 'y': 469}, 'label': 'traffic light', 'confidence': 0.28498277, 'topleft': {'x': 1850, 'y': 430}}]
# Shape of Frame: (1080, 1920, 3)
# Type of Frame:  <class 'numpy.ndarray'>
# FPS 15.2
# Elapsed time = 0.06600213050842285 s
# ++++++++ Video End ++++++++
